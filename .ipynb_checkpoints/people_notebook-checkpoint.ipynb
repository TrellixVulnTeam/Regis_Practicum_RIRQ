# %% [markdown]
# <h1 align='center'>MSDE 692</h1>

# %% [markdown]
# [Global Variables](#Global-Variables)
#
# [Function Definitions](#Function-Definitions)
#
# [Data Cleaning](#Data-Cleaning)
# - [Create Difference CSV File for wikigrabber Spider Runs](#Create-Difference-CSV-File-for-wikigrabber-Spider-Runs)
# - [Text Manipulation](#Text-Manipulation)
# - [WikiGrabber Results Cleaning](#WikiGrabber-Results-Cleaning)
# - [WikiCrawler Results Cleaning](#WikiCrawler-Results-Cleaning)
#     - [Data Type Transformations](#Data-Type-Transformations)
#     - [Create CSV file for each node](#Create-CSV-file-for-each-node)

# %%
import os
import pandas as pd
import neo4j
import numpy as np
import csv
import shutil
import urllib
import codecs
import neo4j

from dateutil import relativedelta
from scrapy.crawler import CrawlerProcess
from pprint import pprint
from deepdiff import DeepDiff
from functools import reduce
from datetime import datetime as dt
from datetime import date
from csv import DictReader, writer

# %%
# https://www.youtube.com/watch?v=5Is-QdbKmEI

# %% [markdown]
# ## Global Variables

# %%
OMIT_LIST = ['Wikipedia:', 'Â', 'Ã', '#', 'index']

# %% [markdown]
# ## Function Definitions

# %%
def csv_reader(csv_file):
    final_list = []

    with open(csv_file, 'r', encoding='unicode_escape') as f:
        input_list = csv.reader(f)

        for row in input_list:
            final_list.append(row[0])
            
    return final_list

# %%
def people_pruner(my_file):
    my_list = []

    with open(my_file, 'r') as f:
        reader = DictReader(f, fieldnames='person')

        for row in reader:
            if [row['p']] not in my_list:
                my_list.append([row['p']])
            else:
                print(f"Duplicate person: {row['p']}")
    
    return my_list

# %%
def csv_writer(my_file, my_mode, my_list):

    with open(my_file, my_mode, newline='', encoding="utf-8") as outfile:
        csv_writer = writer(outfile)

        for row in my_list:
            if not (":" in row or row == 'wiki' or row.startswith(tuple(OMIT_LIST)) or "Ã" in row):
                csv_writer.writerow([row])

# %%
def csv_dict_writer(my_file, my_list, my_mode):
    with open(my_file, my_mode, newline='') as f:
        writer = csv.DictWriter(f, fieldnames=['wiki'])
        
        for row in my_list:
            if ":" not in row and row != 'wiki' and not row.startswith(tuple(OMIT_LIST)):
                writer.writerow({'wiki': row})

# %%
def add_new_wikis(adding_file, gaining_file, base_file):
    """
    Adds newly discovered wiki pages to an accumulative wiki pages file before deleting the previous base file
    used to extract the new wikis. The previous base file is then deleted and the adding_file is renamed to base_file
    for the next grabwikis spider run.
    """
    base_list_tmp = csv_reader(base_file)
    adding_list = csv_reader(adding_file)
    gaining_list = csv_reader(gaining_file)
    base_set = set(base_list_tmp)
    adding_set = set(adding_list)
    gaining_set = set(gaining_list)
    
    new_base_wikis = list(set.difference(base_set, gaining_set))
    new_wikis = list(set.difference(adding_set, gaining_set))
    
    if len(new_wikis) > 0:
        print(f"Adding {len(new_wikis)} new wiki pages to {gaining_file}")
        csv_writer(gaining_file, 'a', new_wikis)
    if len(new_base_wikis) > 0:
        print(f"Adding {len(new_base_wikis)} new base wiki pages to {gaining_file}")
        csv_writer(gaining_file, 'a', new_base_wikis)
#         csv_dict_writer(base_file, new_wikis, 'w')
#         os.remove(adding_file)
    os.remove(base_file)
#     shutil.copy(adding_file, base_file)
    os.remove(adding_file)
    csv_writer(base_file, 'w', new_wikis)

# %%
def clean_df(my_df, out_file):
    all_people_df = my_df.drop_duplicates()
    all_people_df = all_people_df[all_people_df.wiki.str.contains(":")==False]
#     all_people_df['wiki'] = all_people_df['wiki'].apply(lambda x: urllib.parse.unquote(x))
    all_people_df = all_people_df[~all_people_df['wiki'].str[:].str.contains("Ã")]    
    all_people_df = all_people_df[~all_people_df['wiki'].str[0].str.isdigit()]    
    all_people_df.sort_values('wiki', inplace=True)
    all_people_df.set_index('wiki', drop=True, inplace=True)
    all_people_df.to_csv('wikigrabber/all_people.csv', encoding='utf-8')

# %%
urllib.parse.unquote("%C4%90or%C4%91e_Stoj%C5%A1i%C4%87_(Serbian_politician,_1928%E2%80%932014)")
# Out:
# 'Đorđe_Stojšić_(Serbian_politician,_1928–2014)'

# %%
urllib.parse.unquote("Zuzana_%C4%8Caputov%C3%A1")
# Out:
# 'Zuzana_Čaputová'

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Create Difference CSV File for wikigrabber Spider Runs

# %%
add_new_wikis('wikigrabber/people.csv', 'wikicrawler/all_people.csv', 'wikigrabber/people_base.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-f15519e35c21> in <module>
# ----> 1 add_new_wikis('wikigrabber/people.csv', 'wikicrawler/all_people.csv', 'wikigrabber/people_base.csv')
#
# <ipython-input-8-24555fd0248f> in add_new_wikis(adding_file, gaining_file, base_file)
#       6     """
#       7     base_list_tmp = csv_reader(base_file)
# ----> 8     adding_list = csv_reader(adding_file)
#       9     gaining_list = csv_reader(gaining_file)
#      10     base_set = set(base_list_tmp)
#
# <ipython-input-4-23c926ad8978> in csv_reader(csv_file)
#       2     final_list = []
#       3
# ----> 4     with open(csv_file, 'r', encoding='unicode_escape') as f:
#       5         input_list = csv.reader(f)
#       6
#
# FileNotFoundError: [Errno 2] No such file or directory: 'wikigrabber/people.csv'

# %%
df = pd.read_csv('wikigrabber/all_people.csv', encoding='unicode_escape')
# df['wiki'] = df['wiki'].apply(lambda x: urllib.parse.unquote(x))
df.to_csv('wikigrabber/people_unclean.csv', encoding='unicode_escape')
df
# Out:
#                                       wiki
# 0                       %C3%81kos_Birtalan
# 1      %C3%81lfhei%C3%B0ur_Ingad%C3%B3ttir
# 2           %C3%81lvaro_Ara%C3%BAjo_Castro
# 3            %C3%81lvaro_El%C3%ADas_Loredo
# 4           %C3%81lvaro_G%C3%B3mez_Hurtado
# ...                                    ...
# 75803                          Chris_Licht
# 75804                          Megyn_Kelly
# 75805                           3_(number)
# 75806                      Michael_Jackson
# 75807                        Brian_Stelter
#
# [75808 rows x 1 columns]

# %% [markdown]
# ### Text Manipulation

# %%
df = pd.read_csv('wikigrabber/people.csv', encoding='unicode_escape')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_47136/168099149.py in <module>
# ----> 1 df = pd.read_csv('wikigrabber/people.csv', encoding='unicode_escape')
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'wikigrabber/people.csv'

# %%
df.to_csv('wikigrabber/people_unclean.csv')

# %%
df['name'] = df['name'].apply(lambda x: x.strip())
df['name'] = df['name'].apply(lambda x: x.replace(' ', '_'))
df
# Out:
#                           name
# 0              Adewale_Adeyemo
# 1               Afsin_Yurdakul
# 2                Albert_Bourla
# 3                    Alex_Karp
# 4                    Ana_Pinho
# ..                         ...
# 398                Mark_Tucker
# 399                Jessica_Uhl
# 400  Ulrik_Vestergaard_Knudsen
# 401              Darren_Walker
# 402             Dieter_Zetsche
#
# [403 rows x 1 columns]

# %%
df.to_csv('wikicrawler/all_people.csv')

# %%
all_people_df = df.drop_duplicates()
all_people_df = all_people_df[all_people_df.wiki.str.contains(":")==False]
all_people_df.sort_values('wiki', inplace=True)
all_people_df.set_index('wiki', drop=True, inplace=True)
all_people_df.to_csv('wikigrabber/all_people.csv')
all_people_df
# Out:
# Empty DataFrame
# Columns: []
# Index: [(Barbara)_Hazel_Guggenheim_King-Farlow_McKinley, A.A._Ames, A.P.J._Abdul_Kalam, A.T._Smith, A.V._Balakrishnan, A.W._Dirlam, A._A._Ames, A._A._Gill, A._A._Purcell, A._Amirthalingam, A._Andrew_Hauk, A._B._Dilworth, A._B._Krongard, A._B._Swindell, A._Bartlett_Giamatti, A._Bruce_Bielaski, A._C._Bartulis, A._C._Bearss, A._C._Gibbs, A._C._Lyles, A._C._Schiffler, A._Carter_Wilder, A._Carville_Foster,_Jr., A._Clarke_Dodge, A._D._Rice, A._David_Buckingham, A._Devitt_Vanech, A._Douglas_Stone, A._Elizabeth_Jones, A._F._M._Ahsanuddin_Chowdhury, A._F._Maciejewski, A._F._Summer, A._G._Lancione, A._G._S._Ram_Babu, A._H._Greenhalgh, A._H._Lightstone, A._Harry_Moore, A._Homer_Byington, A._Hyatt_Mayor, A._Hyatt_Smith, A._J._McNamara, A._J._Mundella, A._J._Nock, A._James_Barnes, A._James_Manchin, A._Jeff_McLemore, A._Joe_Canada_Jr., A._Joe_Fish, A._Joseph_DeNucci, A._K._Antony, A._K._Balan, A._K._Brohi, A._Keith_Bissell, A._L._M._Athaullah, A._L._Philpott, A._L._Rasmussen, A._L._Strand, A._LeRoy_Greason, A._Lee_Chandler, A._Leon_Higginbotham_Jr., A._Linwood_Holton_Jr., A._Marvin_Quattlebaum_Jr., A._Mitchell_Palmer, A._O._L._Atkin, A._P._Balachandran, A._P._J._Abdul_Kalam, A._P._Jayasuriya, A._P._Lutali, A._Paul_Alivisatos, A._Piatt_Andrew, A._Pratt_Kessler, A._Q._M._Badruddoza_Chowdhury, A._R._McCabe, A._R._Meek, A._Ray_Olpin, A._Raymond_Randolph, A._Richard_Caputo, A._Richard_Newton, A._Ronald_Button, A._RÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ¼stow, A._RÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ¼stow, A._S._J._Carnahan, A._S._M._Abdur_Rab, A._Scott_Sloan, A._T._M._Abdul_Mateen, A._T._M._Afzal, A._U._Fuimaono, A._U._Wyman, A._V._Alexander,_1st_Earl_Alexander_of_Hillsborough, A._Vernon_Weaver, A._Victor_Donahey, A._Victor_Thomas, A._W._Norblad, A._W._Tiffany, A._Walter_Norblad, A._Walton_Litz, A._Wess_Mitchell, A._William_Maupin, A._Willis_Robertson, A._Y._Milam, ...]
#
# [71757 rows x 0 columns]

# %%
url_df = pd.read_csv('wikigrabber/all_people.csv', encoding='unicode_escape')
url_df
# Out:
#                       wiki
# 0       %C3%81kos_Birtalan
# 1        %C3%81lvaro_Nadal
# 2        %C3%81ngel_Acebes
# 3      %C3%81ngeles_Amador
# 4       %C3%85sa_Lindhagen
# ...                    ...
# 68503         Zweli_Mkhize
# 68504  Zygmunt_Janiszewski
# 68505   Zygmunt_Zalcwasser
# 68506           Zyon_Braun
# 68507        Zyta_Gilowska
#
# [68508 rows x 1 columns]

# %%
url_df['wiki'] = url_df['wiki'].apply(lambda x: urllib.parse.unquote(x))

# %%
url_df.to_csv('wikigrabber/all_people.csv')

# %% [markdown]
# ### WikiGrabber Results Cleaning

# %%
df = pd.read_csv('wikigrabber/all_people.csv', encoding='unicode_escape')
df
# Out:
#                                       wiki
# 0                       %C3%81kos_Birtalan
# 1      %C3%81lfhei%C3%B0ur_Ingad%C3%B3ttir
# 2           %C3%81lvaro_Ara%C3%BAjo_Castro
# 3            %C3%81lvaro_El%C3%ADas_Loredo
# 4           %C3%81lvaro_G%C3%B3mez_Hurtado
# ...                                    ...
# 75335                           Zwentibold
# 75336                  Zygmunt_Janiszewski
# 75337                   Zygmunt_Zalcwasser
# 75338                           Zyon_Braun
# 75339                        Zyta_Gilowska
#
# [75340 rows x 1 columns]

# %%
df['wiki'] = df['wiki'].apply(lambda x: x if not x.startswith())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47952 entries, 0 to 47951
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       47251 non-null  object
#  1   full_name  16425 non-null  object
#  2   born       45753 non-null  object
#  3   died       28590 non-null  object
# dtypes: object(4)
# memory usage: 1.5+ MB

# %% [markdown]
# ### WikiCrawler Results Cleaning

# %%
df = pd.read_csv('wikicrawler/wikicrawler_results.csv', encoding='unicode_escape')
df
# Out:
#                                name                full_name        born  \
# 0                   Michael Jackson   Michael Joseph Jackson  1958-08-29
# 1             Ãlvaro ElÃ­as Loredo                      NaN  1947-02-19
# 2                           Charles                      NaN  1948-11-14
# 3                         Kat Timpf    Katherine Clare Timpf  1988-10-29
# 4                         Elon Musk          Elon Reeve Musk  1971-06-28
# ...                             ...                      ...         ...
# 65153                  Zweli Mkhize  Zwelini Lawrence Mkhize  1956-02-02
# 65154                    Zyon Braun               Zyon Braun  1994-08-17
# 65155             Zuzana ZvolenskÃ¡                      NaN  1972-01-27
# 65156                 Zyta Gilowska                      NaN  1949-07-07
# 65157  Zvezdelina Entcheva Stankova                      NaN  1969-09-15
#
#                 died        citizenship  \
# 0      June 25, 2009                NaN
# 1                NaN                NaN
# 2                NaN                NaN
# 3                NaN                NaN
# 4                NaN  United States,[1]
# ...              ...                ...
# 65153            NaN                NaN
# 65154            NaN                NaN
# 65155            NaN                NaN
# 65156   5 April 2016                NaN
# 65157            NaN                NaN
#
#                                                known_for  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3          Gutfeld!,National Review,Fox News Specialists
# 4                                                    NaN
# ...                                                  ...
# 65153                                                NaN
# 65154                                                NaN
# 65155                                                NaN
# 65156                                                NaN
# 65157  Skew-merged permutation,permutations with forb...
#
#                                                  schools degrees  \
# 0                                                    NaN     NaN
# 1              Autonomous University of San Luis PotosÃ­     NaN
# 2                    Gordonstoun,University of Cambridge     NaN
# 3                                   Hillsdale College,BA     NaN
# 4                             University of Pennsylvania   BA,BS
# ...                                                  ...     ...
# 65153                           University of Natal,M.B.     NaN
# 65154  FOM University of Applied Sciences for Economi...     NaN
# 65155                                Comenius University     NaN
# 65156  Warsaw University,Maria Curie-Sklodowska Unive...     NaN
# 65157               Bryn Mawr College,Harvard University     NaN
#
#       organizations                                      institutions  ...  \
# 0               NaN                                               NaN  ...
# 1               NaN                                               NaN  ...
# 2               NaN                                               NaN  ...
# 3               NaN                                               NaN  ...
# 4               NaN                                               NaN  ...
# ...             ...                                               ...  ...
# 65153           NaN                                               NaN  ...
# 65154           NaN                                               NaN  ...
# 65155           NaN                                               NaN  ...
# 65156           NaN                                               NaN  ...
# 65157           NaN  Mills College,University of California, Berkeley  ...
#
#          house                                              title  \
# 0      Jackson                                                NaN
# 1          NaN                                                NaN
# 2      Windsor                                                NaN
# 3          NaN                                                NaN
# 4         Musk  Founder, CEO, and Chief Engineer of ,SpaceX,CE...
# ...        ...                                                ...
# 65153      NaN                                                NaN
# 65154      NaN                                                NaN
# 65155      NaN                                                NaN
# 65156      NaN                                                NaN
# 65157      NaN                                                NaN
#
#       doctoral_advisor       fields  \
# 0                  NaN          NaN
# 1                  NaN          NaN
# 2                  NaN          NaN
# 3                  NaN          NaN
# 4                  NaN          NaN
# ...                ...          ...
# 65153              NaN          NaN
# 65154              NaN          NaN
# 65155              NaN          NaN
# 65156              NaN          NaN
# 65157       Joe Harris  Mathematics
#
#                                                positions  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 65153  Minister of Health of South Africa,Minister of...
# 65154  Leader of the Free Democratic Party in Branden...
# 65155                                 Minister of Health
# 65156          Minister of Finance,Deputy Prime Minister
# 65157                                                NaN
#
#                                      occupation employer  \
# 0      Singer,songwriter,dancer,record producer      NaN
# 1                         Lawyer and politician      NaN
# 2                                           NaN      NaN
# 3                        Television personality      NaN
# 4                                           NaN      NaN
# ...                                         ...      ...
# 65153                         Doctor,legislator      NaN
# 65154                         Politician,Banker      NaN
# 65155                                Politician      NaN
# 65156                                       NaN      NaN
# 65157                                       NaN      NaN
#
#                     political_party board_member  \
# 0                               NaN          NaN
# 1                               PAN          NaN
# 2                               NaN          NaN
# 3                               NaN          NaN
# 4                               NaN          NaN
# ...                             ...          ...
# 65153     African National Congress          NaN
# 65154         Free Democratic Party          NaN
# 65155    Direction-Social Democracy          NaN
# 65156  Freedom Union,Civic Platform          NaN
# 65157                           NaN          NaN
#
#                                                   labels
# 0      Steeltown,Motown,Epic,Legacy,Sony,MJJ Productions
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 65153                                                NaN
# 65154                                                NaN
# 65155                                                NaN
# 65156                                                NaN
# 65157                                                NaN
#
# [65158 rows x 24 columns]

# %%
# Delete blank records 
df_full = df.dropna(subset=['name', 'born'])
df_full = df_full.replace({np.nan: None})
df_full['born'] = df.born.apply(lambda x: pd.to_datetime(x, errors='coerce'))
df_full['died'] = df.died.apply(lambda x: pd.to_datetime(x, errors='coerce'))
# df_full = df_full[pd.to_datetime(df_full['born'], errors='coerce').notna()]
# df_full = df_full[pd.to_datetime(df_full['died'], errors='coerce').notna()]
df_full['died'] = df_full['died'].astype(str).replace({'NaT': None})
df_full = df_full.dropna(subset=['born'])
df_full
# Out:
#                                name                full_name       born  \
# 0                   Michael Jackson   Michael Joseph Jackson 1958-08-29
# 1             Ãlvaro ElÃ­as Loredo                     None 1947-02-19
# 2                           Charles                     None 1948-11-14
# 3                         Kat Timpf    Katherine Clare Timpf 1988-10-29
# 4                         Elon Musk          Elon Reeve Musk 1971-06-28
# ...                             ...                      ...        ...
# 65153                  Zweli Mkhize  Zwelini Lawrence Mkhize 1956-02-02
# 65154                    Zyon Braun               Zyon Braun 1994-08-17
# 65155             Zuzana ZvolenskÃ¡                     None 1972-01-27
# 65156                 Zyta Gilowska                     None 1949-07-07
# 65157  Zvezdelina Entcheva Stankova                     None 1969-09-15
#
#              died        citizenship  \
# 0      2009-06-25               None
# 1            None               None
# 2            None               None
# 3            None               None
# 4            None  United States,[1]
# ...           ...                ...
# 65153        None               None
# 65154        None               None
# 65155        None               None
# 65156  2016-04-05               None
# 65157        None               None
#
#                                                known_for  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3          Gutfeld!,National Review,Fox News Specialists
# 4                                                   None
# ...                                                  ...
# 65153                                               None
# 65154                                               None
# 65155                                               None
# 65156                                               None
# 65157  Skew-merged permutation,permutations with forb...
#
#                                                  schools degrees  \
# 0                                                   None    None
# 1              Autonomous University of San Luis PotosÃ­    None
# 2                    Gordonstoun,University of Cambridge    None
# 3                                   Hillsdale College,BA    None
# 4                             University of Pennsylvania   BA,BS
# ...                                                  ...     ...
# 65153                           University of Natal,M.B.    None
# 65154  FOM University of Applied Sciences for Economi...    None
# 65155                                Comenius University    None
# 65156  Warsaw University,Maria Curie-Sklodowska Unive...    None
# 65157               Bryn Mawr College,Harvard University    None
#
#       organizations                                      institutions  ...  \
# 0              None                                              None  ...
# 1              None                                              None  ...
# 2              None                                              None  ...
# 3              None                                              None  ...
# 4              None                                              None  ...
# ...             ...                                               ...  ...
# 65153          None                                              None  ...
# 65154          None                                              None  ...
# 65155          None                                              None  ...
# 65156          None                                              None  ...
# 65157          None  Mills College,University of California, Berkeley  ...
#
#          house                                              title  \
# 0      Jackson                                               None
# 1         None                                               None
# 2      Windsor                                               None
# 3         None                                               None
# 4         Musk  Founder, CEO, and Chief Engineer of ,SpaceX,CE...
# ...        ...                                                ...
# 65153     None                                               None
# 65154     None                                               None
# 65155     None                                               None
# 65156     None                                               None
# 65157     None                                               None
#
#       doctoral_advisor       fields  \
# 0                 None         None
# 1                 None         None
# 2                 None         None
# 3                 None         None
# 4                 None         None
# ...                ...          ...
# 65153             None         None
# 65154             None         None
# 65155             None         None
# 65156             None         None
# 65157       Joe Harris  Mathematics
#
#                                                positions  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 65153  Minister of Health of South Africa,Minister of...
# 65154  Leader of the Free Democratic Party in Branden...
# 65155                                 Minister of Health
# 65156          Minister of Finance,Deputy Prime Minister
# 65157                                               None
#
#                                      occupation employer  \
# 0      Singer,songwriter,dancer,record producer     None
# 1                         Lawyer and politician     None
# 2                                          None     None
# 3                        Television personality     None
# 4                                          None     None
# ...                                         ...      ...
# 65153                         Doctor,legislator     None
# 65154                         Politician,Banker     None
# 65155                                Politician     None
# 65156                                      None     None
# 65157                                      None     None
#
#                     political_party board_member  \
# 0                              None         None
# 1                               PAN         None
# 2                              None         None
# 3                              None         None
# 4                              None         None
# ...                             ...          ...
# 65153     African National Congress         None
# 65154         Free Democratic Party         None
# 65155    Direction-Social Democracy         None
# 65156  Freedom Union,Civic Platform         None
# 65157                          None         None
#
#                                                   labels
# 0      Steeltown,Motown,Epic,Legacy,Sony,MJJ Productions
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 65153                                               None
# 65154                                               None
# 65155                                               None
# 65156                                               None
# 65157                                               None
#
# [57789 rows x 24 columns]

# %% [markdown]
# ### Data Type Transformations

# %%
# Function creates list from comma separated values in string
# Removes '' and '\n' values
def str_to_list(my_str):
    final_vec = []
#     print(type(my_str))
    if my_str != None:
        vector = [v for v in my_str.split(',') if v not in ['', '\n']]
        return vector

# %%
multi_val_cols = ['title',
                  'positions',
                  'institutions',
                  'occupation',
                  'labels',
                  'fields',
                  'known_for',
                  'schools',
                  'degrees',
                  'spouses',
                  'parents',
                  'relatives',
                  'political_party',
                  'employer',
                  'board_member']

# %%
# Clean empty values in cells
df_full[multi_val_cols] = np.vectorize(str_to_list)(df_full[multi_val_cols])
df_full
# Out:
#                                name                full_name       born  \
# 0                   Michael Jackson   Michael Joseph Jackson 1958-08-29
# 1             Ãlvaro ElÃ­as Loredo                     None 1947-02-19
# 2                           Charles                     None 1948-11-14
# 3                         Kat Timpf    Katherine Clare Timpf 1988-10-29
# 4                         Elon Musk          Elon Reeve Musk 1971-06-28
# ...                             ...                      ...        ...
# 65153                  Zweli Mkhize  Zwelini Lawrence Mkhize 1956-02-02
# 65154                    Zyon Braun               Zyon Braun 1994-08-17
# 65155             Zuzana ZvolenskÃ¡                     None 1972-01-27
# 65156                 Zyta Gilowska                     None 1949-07-07
# 65157  Zvezdelina Entcheva Stankova                     None 1969-09-15
#
#              died        citizenship  \
# 0      2009-06-25               None
# 1            None               None
# 2            None               None
# 3            None               None
# 4            None  United States,[1]
# ...           ...                ...
# 65153        None               None
# 65154        None               None
# 65155        None               None
# 65156  2016-04-05               None
# 65157        None               None
#
#                                                known_for  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3      [Gutfeld!, National Review, Fox News Specialists]
# 4                                                   None
# ...                                                  ...
# 65153                                               None
# 65154                                               None
# 65155                                               None
# 65156                                               None
# 65157  [Skew-merged permutation, permutations with fo...
#
#                                                  schools   degrees  \
# 0                                                   None      None
# 1            [Autonomous University of San Luis PotosÃ­]      None
# 2                 [Gordonstoun, University of Cambridge]      None
# 3                                [Hillsdale College, BA]      None
# 4                           [University of Pennsylvania]  [BA, BS]
# ...                                                  ...       ...
# 65153                        [University of Natal, M.B.]      None
# 65154  [FOM University of Applied Sciences for Econom...      None
# 65155                              [Comenius University]      None
# 65156  [Warsaw University, Maria Curie-Sklodowska Uni...      None
# 65157            [Bryn Mawr College, Harvard University]      None
#
#       organizations                                       institutions  ...  \
# 0              None                                               None  ...
# 1              None                                               None  ...
# 2              None                                               None  ...
# 3              None                                               None  ...
# 4              None                                               None  ...
# ...             ...                                                ...  ...
# 65153          None                                               None  ...
# 65154          None                                               None  ...
# 65155          None                                               None  ...
# 65156          None                                               None  ...
# 65157          None  [Mills College, University of California,  Ber...  ...
#
#          house                                              title  \
# 0      Jackson                                               None
# 1         None                                               None
# 2      Windsor                                               None
# 3         None                                               None
# 4         Musk  [Founder,  CEO,  and Chief Engineer of , Space...
# ...        ...                                                ...
# 65153     None                                               None
# 65154     None                                               None
# 65155     None                                               None
# 65156     None                                               None
# 65157     None                                               None
#
#       doctoral_advisor         fields  \
# 0                 None           None
# 1                 None           None
# 2                 None           None
# 3                 None           None
# 4                 None           None
# ...                ...            ...
# 65153             None           None
# 65154             None           None
# 65155             None           None
# 65156             None           None
# 65157       Joe Harris  [Mathematics]
#
#                                                positions  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 65153  [Minister of Health of South Africa, Minister ...
# 65154  [Leader of the Free Democratic Party in Brande...
# 65155                               [Minister of Health]
# 65156       [Minister of Finance, Deputy Prime Minister]
# 65157                                               None
#
#                                           occupation employer  \
# 0      [Singer, songwriter, dancer, record producer]     None
# 1                            [Lawyer and politician]     None
# 2                                               None     None
# 3                           [Television personality]     None
# 4                                               None     None
# ...                                              ...      ...
# 65153                           [Doctor, legislator]     None
# 65154                           [Politician, Banker]     None
# 65155                                   [Politician]     None
# 65156                                           None     None
# 65157                                           None     None
#
#                        political_party board_member  \
# 0                                 None         None
# 1                                [PAN]         None
# 2                                 None         None
# 3                                 None         None
# 4                                 None         None
# ...                                ...          ...
# 65153      [African National Congress]         None
# 65154          [Free Democratic Party]         None
# 65155     [Direction-Social Democracy]         None
# 65156  [Freedom Union, Civic Platform]         None
# 65157                             None         None
#
#                                                   labels
# 0      [Steeltown, Motown, Epic, Legacy, Sony, MJJ Pr...
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 65153                                               None
# 65154                                               None
# 65155                                               None
# 65156                                               None
# 65157                                               None
#
# [57789 rows x 24 columns]

# %%
# Function calculateds age
def calc_age(my_born, my_died):
    born = pd.to_datetime(my_born)
    if my_died is None:
        today = dt.now()
        return today.year - born.year - ((today.month, today.day) < (born.month, born.day))
    else:
#         my_age = relativedelta.relativedelta(died - born)
        died = pd.to_datetime(my_died)
        return (died - born).days / 365

# %%
chars_to_remove = ['c', '.', 'circa', 'Unkown', '/']

# Should handle 
def convert_circa_dates(my_date):
    if my_date.startswith(tuple(chars_to_remove)):
        clean_date = ''.join([c for c in my_date if c not in chars_to_remove])
        return clean_date
    else:
        return my_date

# %%
def datetime_to_mmddyyyy(my_date):
    if my_date is not None:
        return dt.strftime('%Y-%m-%d', '%m/%d/%Y')
    else:
        return None

# %%
df_full['age']= np.vectorize(calc_age)(df_full['born'], df_full['died'])
df_full
# Out:
#                                name                full_name       born  \
# 0                   Michael Jackson   Michael Joseph Jackson 1958-08-29
# 1             Ãlvaro ElÃ­as Loredo                     None 1947-02-19
# 2                           Charles                     None 1948-11-14
# 3                         Kat Timpf    Katherine Clare Timpf 1988-10-29
# 4                         Elon Musk          Elon Reeve Musk 1971-06-28
# ...                             ...                      ...        ...
# 65153                  Zweli Mkhize  Zwelini Lawrence Mkhize 1956-02-02
# 65154                    Zyon Braun               Zyon Braun 1994-08-17
# 65155             Zuzana ZvolenskÃ¡                     None 1972-01-27
# 65156                 Zyta Gilowska                     None 1949-07-07
# 65157  Zvezdelina Entcheva Stankova                     None 1969-09-15
#
#              died        citizenship  \
# 0      2009-06-25               None
# 1            None               None
# 2            None               None
# 3            None               None
# 4            None  United States,[1]
# ...           ...                ...
# 65153        None               None
# 65154        None               None
# 65155        None               None
# 65156  2016-04-05               None
# 65157        None               None
#
#                                                known_for  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3      [Gutfeld!, National Review, Fox News Specialists]
# 4                                                   None
# ...                                                  ...
# 65153                                               None
# 65154                                               None
# 65155                                               None
# 65156                                               None
# 65157  [Skew-merged permutation, permutations with fo...
#
#                                                  schools   degrees  \
# 0                                                   None      None
# 1            [Autonomous University of San Luis PotosÃ­]      None
# 2                 [Gordonstoun, University of Cambridge]      None
# 3                                [Hillsdale College, BA]      None
# 4                           [University of Pennsylvania]  [BA, BS]
# ...                                                  ...       ...
# 65153                        [University of Natal, M.B.]      None
# 65154  [FOM University of Applied Sciences for Econom...      None
# 65155                              [Comenius University]      None
# 65156  [Warsaw University, Maria Curie-Sklodowska Uni...      None
# 65157            [Bryn Mawr College, Harvard University]      None
#
#       organizations                                       institutions  ...  \
# 0              None                                               None  ...
# 1              None                                               None  ...
# 2              None                                               None  ...
# 3              None                                               None  ...
# 4              None                                               None  ...
# ...             ...                                                ...  ...
# 65153          None                                               None  ...
# 65154          None                                               None  ...
# 65155          None                                               None  ...
# 65156          None                                               None  ...
# 65157          None  [Mills College, University of California,  Ber...  ...
#
#                                                    title doctoral_advisor  \
# 0                                                   None             None
# 1                                                   None             None
# 2                                                   None             None
# 3                                                   None             None
# 4      [Founder,  CEO,  and Chief Engineer of , Space...             None
# ...                                                  ...              ...
# 65153                                               None             None
# 65154                                               None             None
# 65155                                               None             None
# 65156                                               None             None
# 65157                                               None       Joe Harris
#
#               fields                                          positions  \
# 0               None                                               None
# 1               None                                               None
# 2               None                                               None
# 3               None                                               None
# 4               None                                               None
# ...              ...                                                ...
# 65153           None  [Minister of Health of South Africa, Minister ...
# 65154           None  [Leader of the Free Democratic Party in Brande...
# 65155           None                               [Minister of Health]
# 65156           None       [Minister of Finance, Deputy Prime Minister]
# 65157  [Mathematics]                                               None
#
#                                           occupation employer  \
# 0      [Singer, songwriter, dancer, record producer]     None
# 1                            [Lawyer and politician]     None
# 2                                               None     None
# 3                           [Television personality]     None
# 4                                               None     None
# ...                                              ...      ...
# 65153                           [Doctor, legislator]     None
# 65154                           [Politician, Banker]     None
# 65155                                   [Politician]     None
# 65156                                           None     None
# 65157                                           None     None
#
#                        political_party board_member  \
# 0                                 None         None
# 1                                [PAN]         None
# 2                                 None         None
# 3                                 None         None
# 4                                 None         None
# ...                                ...          ...
# 65153      [African National Congress]         None
# 65154          [Free Democratic Party]         None
# 65155     [Direction-Social Democracy]         None
# 65156  [Freedom Union, Civic Platform]         None
# 65157                             None         None
#
#                                                   labels        age
# 0      [Steeltown, Motown, Epic, Legacy, Sony, MJJ Pr...  50.857534
# 1                                                   None  75.000000
# 2                                                   None  73.000000
# 3                                                   None  33.000000
# 4                                                   None  50.000000
# ...                                                  ...        ...
# 65153                                               None  66.000000
# 65154                                               None  27.000000
# 65155                                               None  50.000000
# 65156                                               None  66.791781
# 65157                                               None  52.000000
#
# [57789 rows x 25 columns]

# %%
schools_df = df_full[['name', 'schools']]
schools_df
# Out:
#                                name  \
# 0                   Michael Jackson
# 1             Ãlvaro ElÃ­as Loredo
# 2                           Charles
# 3                         Kat Timpf
# 4                         Elon Musk
# ...                             ...
# 65153                  Zweli Mkhize
# 65154                    Zyon Braun
# 65155             Zuzana ZvolenskÃ¡
# 65156                 Zyta Gilowska
# 65157  Zvezdelina Entcheva Stankova
#
#                                                  schools
# 0                                                   None
# 1            [Autonomous University of San Luis PotosÃ­]
# 2                 [Gordonstoun, University of Cambridge]
# 3                                [Hillsdale College, BA]
# 4                           [University of Pennsylvania]
# ...                                                  ...
# 65153                        [University of Natal, M.B.]
# 65154  [FOM University of Applied Sciences for Econom...
# 65155                              [Comenius University]
# 65156  [Warsaw University, Maria Curie-Sklodowska Uni...
# 65157            [Bryn Mawr College, Harvard University]
#
# [57789 rows x 2 columns]

# %%
pared_schools_df = schools_df.dropna(how='any')
pared_schools_df
# Out:
#                                name  \
# 1             Ãlvaro ElÃ­as Loredo
# 2                           Charles
# 3                         Kat Timpf
# 4                         Elon Musk
# 5                  Timothy Olyphant
# ...                             ...
# 65153                  Zweli Mkhize
# 65154                    Zyon Braun
# 65155             Zuzana ZvolenskÃ¡
# 65156                 Zyta Gilowska
# 65157  Zvezdelina Entcheva Stankova
#
#                                                  schools
# 1            [Autonomous University of San Luis PotosÃ­]
# 2                 [Gordonstoun, University of Cambridge]
# 3                                [Hillsdale College, BA]
# 4                           [University of Pennsylvania]
# 5               [University of Southern California, BFA]
# ...                                                  ...
# 65153                        [University of Natal, M.B.]
# 65154  [FOM University of Applied Sciences for Econom...
# 65155                              [Comenius University]
# 65156  [Warsaw University, Maria Curie-Sklodowska Uni...
# 65157            [Bryn Mawr College, Harvard University]
#
# [33732 rows x 2 columns]

# %%
exploded_schools_df = pared_schools_df.explode(column='schools')
exploded_schools_df
# Out:
#                                name                                    schools
# 1             Ãlvaro ElÃ­as Loredo  Autonomous University of San Luis PotosÃ­
# 2                           Charles                                Gordonstoun
# 2                           Charles                    University of Cambridge
# 3                         Kat Timpf                          Hillsdale College
# 3                         Kat Timpf                                         BA
# ...                             ...                                        ...
# 65155             Zuzana ZvolenskÃ¡                        Comenius University
# 65156                 Zyta Gilowska                          Warsaw University
# 65156                 Zyta Gilowska          Maria Curie-Sklodowska University
# 65157  Zvezdelina Entcheva Stankova                          Bryn Mawr College
# 65157  Zvezdelina Entcheva Stankova                         Harvard University
#
# [62017 rows x 2 columns]

# %%
exploded_schools_df['attended'] = 'attended'
exploded_schools_df
# Out:
#                                name  \
# 1             Ãlvaro ElÃ­as Loredo
# 2                           Charles
# 2                           Charles
# 3                         Kat Timpf
# 3                         Kat Timpf
# ...                             ...
# 65155             Zuzana ZvolenskÃ¡
# 65156                 Zyta Gilowska
# 65156                 Zyta Gilowska
# 65157  Zvezdelina Entcheva Stankova
# 65157  Zvezdelina Entcheva Stankova
#
#                                          schools  attended
# 1      Autonomous University of San Luis PotosÃ­  attended
# 2                                    Gordonstoun  attended
# 2                        University of Cambridge  attended
# 3                              Hillsdale College  attended
# 3                                             BA  attended
# ...                                          ...       ...
# 65155                        Comenius University  attended
# 65156                          Warsaw University  attended
# 65156          Maria Curie-Sklodowska University  attended
# 65157                          Bryn Mawr College  attended
# 65157                         Harvard University  attended
#
# [62017 rows x 3 columns]

# %%
exploded_schools_df.to_csv('wikicrawler/schools_attended.csv')

# %%
df_full.set_index('name', inplace=True)

# %%
df_full.to_csv('wikicrawler/wikicrawler_no_blanks.csv')

# %% [markdown]
# ### Create CSV file for each node

# %% [markdown]
# ### Organizations

# %%
df_orgs = df['organizations'].dropna()
df_orgs
# Out:
# 261      Creative Commons,Reddit,Open Library,DeadDrop,...
# 2495                                        Wertheim & Co.
# 4282     Public Radio of Armenia , Ar Radio Intercontin...
# 5034                                   Austen Riggs Center
# 5106                                        AHA Foundation
#                                ...
# 58999                               University of Michigan
# 59147        Gerrit W. Gong,Ulisses Soares,Robert D. Hales
# 60446                                                   UN
# 61637       American Association of Physicists in Medicine
# 61740                            Levin & Co, Johnston & Co
# Name: organizations, Length: 77, dtype: object

# %%
my_orgs = df_orgs.to_list()

# %%
for l in my_orgs:
    print(l)
# Out:
# Creative Commons,Reddit,Open Library,DeadDrop,Progressive Change Campaign Committee,Demand Progress,ThoughtWorks,Tor2web
# Wertheim & Co.
# Public Radio of Armenia , Ar Radio Intercontinental
# Austen Riggs Center
# AHA Foundation
# One Campaign
# Creative Artists Agency
# Colorado Springs Symphony Orchestra,Boston Landmarks Orchestra
# Executive Council of Hong Kong
# Anbang
# NXIVM
# Young Pioneers,[6]
# Mormon Tabernacle Choir,Utah Symphony Orchestra Board
# Paul and Daisy Soros Fellowships for New Americans
# CAMH,Jack.org
# Teneo
# Lincoln's Inn Fields
#
# ,Chorgemeinschaft Neubeuern,
# ,KlangVerwaltung,
# ,BUND,
# ,Herrenchiemsee Festival,
#
# Jeffrey R. Holland
# Creative Armenia , Avalanche Entertainment
# University of Oxford
# Smokehouse Pictures,Casamigos
# Rudger Clawson,[1]
# Baptist State Convention of North Carolina,Baylor University
# TerraMar Project
# D. Todd Christofferson
# Americans for Tax Reform
# Women's Social and Political Union
# Metropolitan Steamship Company
# Henry B. Eyring
# Black Panther Party
# International Monetary Fund
# Bank of England
# Gujarat Kisan Parishad, Mahagujarat Janata Parishad, Nutan Mahagujarat Janata Parishad
# Brookmeade Stable
# No additional apostles ordained,[c]
# Constitutional Council of France
# Flood & O'Brien,Consolidated Virginia Mining Company,Bank of Nevada
# Quentin L. Cook,Henry B. Eyring
# Jigsaw,Council on Foreign Relations
# Rivington Street Settlement
# Catholic Church
# Orange County Sheriff's Office
# John Templeton Foundation
# Liberal Party
# Geneva Steel Company
# New Jersey Casino Control Commission
#
# ,Donda,
# ,Yeezy,
#
# Llangollen Farm Stable
# National Star College
# Richard G. Scott
# Cyber Civil Rights Initiative
# Bryn Mawr College,Andrew W. Mellon Foundation,American Philosophical Society
# Wertheim & Co.
# Occidental Petroleum,Oral Roberts University
# Center for Libertarian Studies,Cato Institute,Mises Institute
# ANTIAIDS Foundation,UNAIDS
# Vienna Circle
# ITA,Embraer,Petrobras,Brazilian government,Varig
# Actors Studio
# Qinchuan Dadi Investment Limited
# Congress Socialist Party,Indian National Congress,Peasants and Workers Party of India
# Congress Socialist Party,Indian National Congress,Peasants and Workers Party of India
# Harold B. Lee
# Harold B. Lee
# Darpana Academy of Performing Arts
# Center for Libertarian Studies,Cato Institute,Mises Institute
# Sarah Campbell Blaffer Foundation
# Barefoot Foundation
# Barefoot Foundation
# African Union Commission
# Auckland Institute
# University of Michigan
# Gerrit W. Gong,Ulisses Soares,Robert D. Hales
# UN
# American Association of Physicists in Medicine
# Levin & Co, Johnston & Co

# %%
orgs_list = []

for l in my_orgs:
    my_orgs = l.split(',')
    for org in my_orgs:
        if org not in orgs_list:
            orgs_list.append(org.strip())

# %%
all_orgs = [x for x in orgs_list if x is not '']
all_orgs
# Out:
# ['Creative Commons',
#  'Reddit',
#  'Open Library',
#  'DeadDrop',
#  'Progressive Change Campaign Committee',
#  'Demand Progress',
#  'ThoughtWorks',
#  'Tor2web',
#  'Wertheim & Co.',
#  'Public Radio of Armenia',
#  'Ar Radio Intercontinental',
#  'Austen Riggs Center',
#  'AHA Foundation',
#  'One Campaign',
#  'Creative Artists Agency',
#  'Colorado Springs Symphony Orchestra',
#  'Boston Landmarks Orchestra',
#  'Executive Council of Hong Kong',
#  'Anbang',
#  'NXIVM',
#  'Young Pioneers',
#  '[6]',
#  'Mormon Tabernacle Choir',
#  'Utah Symphony Orchestra Board',
#  'Paul and Daisy Soros Fellowships for New Americans',
#  'CAMH',
#  'Jack.org',
#  'Teneo',
#  "Lincoln's Inn Fields",
#  'Chorgemeinschaft Neubeuern',
#  'KlangVerwaltung',
#  'BUND',
#  'Herrenchiemsee Festival',
#  'Jeffrey R. Holland',
#  'Creative Armenia',
#  'Avalanche Entertainment',
#  'University of Oxford',
#  'Smokehouse Pictures',
#  'Casamigos',
#  'Rudger Clawson',
#  '[1]',
#  'Baptist State Convention of North Carolina',
#  'Baylor University',
#  'TerraMar Project',
#  'D. Todd Christofferson',
#  'Americans for Tax Reform',
#  "Women's Social and Political Union",
#  'Metropolitan Steamship Company',
#  'Henry B. Eyring',
#  'Black Panther Party',
#  'International Monetary Fund',
#  'Bank of England',
#  'Gujarat Kisan Parishad',
#  'Mahagujarat Janata Parishad',
#  'Nutan Mahagujarat Janata Parishad',
#  'Brookmeade Stable',
#  'No additional apostles ordained',
#  '[c]',
#  'Constitutional Council of France',
#  "Flood & O'Brien",
#  'Consolidated Virginia Mining Company',
#  'Bank of Nevada',
#  'Quentin L. Cook',
#  'Jigsaw',
#  'Council on Foreign Relations',
#  'Rivington Street Settlement',
#  'Catholic Church',
#  "Orange County Sheriff's Office",
#  'John Templeton Foundation',
#  'Liberal Party',
#  'Geneva Steel Company',
#  'New Jersey Casino Control Commission',
#  'Donda',
#  'Yeezy',
#  'Llangollen Farm Stable',
#  'National Star College',
#  'Richard G. Scott',
#  'Cyber Civil Rights Initiative',
#  'Bryn Mawr College',
#  'Andrew W. Mellon Foundation',
#  'American Philosophical Society',
#  'Occidental Petroleum',
#  'Oral Roberts University',
#  'Center for Libertarian Studies',
#  'Cato Institute',
#  'Mises Institute',
#  'ANTIAIDS Foundation',
#  'UNAIDS',
#  'Vienna Circle',
#  'ITA',
#  'Embraer',
#  'Petrobras',
#  'Brazilian government',
#  'Varig',
#  'Actors Studio',
#  'Qinchuan Dadi Investment Limited',
#  'Congress Socialist Party',
#  'Indian National Congress',
#  'Peasants and Workers Party of India',
#  'Harold B. Lee',
#  'Darpana Academy of Performing Arts',
#  'Sarah Campbell Blaffer Foundation',
#  'Barefoot Foundation',
#  'African Union Commission',
#  'Auckland Institute',
#  'University of Michigan',
#  'Gerrit W. Gong',
#  'Ulisses Soares',
#  'Robert D. Hales',
#  'UN',
#  'American Association of Physicists in Medicine',
#  'Levin & Co',
#  'Johnston & Co']

# %%
len(all_orgs)
# Out:
# 113

# %%
orgs_df = pd.DataFrame({'organization': all_orgs})
orgs_df.set_index('organization', inplace=True)
orgs_df.to_csv('wikicrawler/organizations.csv')

# %%
schools_df = df['schools'].dropna()
schools_df
# Out:
# 1                Autonomous University of San Luis PotosÃ­
# 2                      Gordonstoun,University of Cambridge
# 3                                     Hillsdale College,BA
# 4                               University of Pennsylvania
# 5                    University of Southern California,BFA
#                                ...
# 65153                             University of Natal,M.B.
# 65154    FOM University of Applied Sciences for Economi...
# 65155                                  Comenius University
# 65156    Warsaw University,Maria Curie-Sklodowska Unive...
# 65157                 Bryn Mawr College,Harvard University
# Name: schools, Length: 37435, dtype: object

# %%
all_schools = schools_df.copy().to_list()
schools_set = set(all_schools)

# %%
len(schools_set)
# Out:
# 18911

# %%
schools_list = list(schools_set)
len(schools_list)
# Out:
# 18911

# %%
schools_df = pd.DataFrame({'school': schools_list})
schools_df.set_index('school', inplace=True)
schools_df.to_csv('wikicrawler/schools.csv')

# %%
# Drop all rows with no born/died data
df_all_names = df_full.dropna(subset=['born', 'died'])
df_all_names
# Out:
#                           name                full_name         born  \
# 8       Ãlvaro GÃ³mez Hurtado                      NaN   1919-05-08
# 10     Ãlvaro Lloreda Caicedo                      NaN   1903-10-15
# 17            Ãlvaro ObregÃ³n  Ãlvaro ObregÃ³n Salido   1880-02-19
# 19             Michael Jackson   Michael Joseph Jackson   1958-08-29
# 25         Ãsgeir Ãsgeirsson                      NaN  13 May 1894
# ...                        ...                      ...          ...
# 65147       Zviad Gamsakhurdia                      NaN   1939-03-31
# 65148       Zvonimir Äervenko                      NaN   1926-11-13
# 65150            Zvi Griliches                      NaN   1930-09-12
# 65152            Zyta Gilowska                      NaN   1949-07-07
# 65155      Zygmunt Janiszewski                      NaN   1888-07-12
#
#                     died citizenship known_for  \
# 8       November 2, 1995         NaN       NaN
# 10         10 April 1985         NaN       NaN
# 17          17 July 1928         NaN       NaN
# 19         June 25, 2009         NaN       NaN
# 25     15 September 1972         NaN       NaN
# ...                  ...         ...       ...
# 65147   31 December 1993         NaN       NaN
# 65148   17 February 2001         NaN       NaN
# 65150    4 November 1999         NaN       NaN
# 65152       5 April 2016         NaN       NaN
# 65155     3 January 1920         NaN       NaN
#
#                                                  schools degrees  \
# 8                        Pontifical Xavierian University     NaN
# 10                                                   NaN     NaN
# 17                                                   NaN     NaN
# 19                                                   NaN     NaN
# 25                                                   NaN     NaN
# ...                                                  ...     ...
# 65147                                                NaN     NaN
# 65148                                                NaN     NaN
# 65150                 University of Chicago,UCÂ Berkeley     NaN
# 65152  Warsaw University,Maria Curie-Sklodowska Unive...     NaN
# 65155                                University of Paris     NaN
#
#       organizations          institutions  ...    house title  \
# 8               NaN                   NaN  ...      NaN   NaN
# 10              NaN                   NaN  ...      NaN   NaN
# 17              NaN                   NaN  ...      NaN   NaN
# 19              NaN                   NaN  ...  Jackson   NaN
# 25              NaN                   NaN  ...      NaN   NaN
# ...             ...                   ...  ...      ...   ...
# 65147           NaN                   NaN  ...      NaN   NaN
# 65148           NaN                   NaN  ...      NaN   NaN
# 65150           NaN                   NaN  ...      NaN   NaN
# 65152           NaN                   NaN  ...      NaN   NaN
# 65155           NaN  University of Warsaw  ...      NaN   NaN
#
#       doctoral_advisor       fields  \
# 8                  NaN          NaN
# 10                 NaN          NaN
# 17                 NaN          NaN
# 19                 NaN          NaN
# 25                 NaN          NaN
# ...                ...          ...
# 65147              NaN          NaN
# 65148              NaN          NaN
# 65150              NaN    Economics
# 65152              NaN          NaN
# 65155   Henri Lebesgue  Mathematics
#
#                                                positions  \
# 8      15th Colombia Ambassador to France,Colombia Am...
# 10     Colombia Ambassador to Spain,Member of the Sen...
# 17     46th President of Mexico,President of the Mexi...
# 19                                                   NaN
# 25     2nd President of Iceland,6th Prime Minister of...
# ...                                                  ...
# 65147  1st President of Georgia,Chairman of the Supre...
# 65148                                                NaN
# 65150                                                NaN
# 65152          Minister of Finance,Deputy Prime Minister
# 65155                                                NaN
#
#                                      occupation employer  \
# 8                         Journalist,politician      NaN
# 10                                          NaN      NaN
# 17                                          NaN      NaN
# 19     Singer,songwriter,dancer,record producer      NaN
# 25                                          NaN      NaN
# ...                                         ...      ...
# 65147                                       NaN      NaN
# 65148                                       NaN      NaN
# 65150                                       NaN      NaN
# 65152                                       NaN      NaN
# 65155                                       NaN      NaN
#
#                                  political_party board_member  \
# 8                                   Conservative          NaN
# 10                                  Conservative          NaN
# 17                                Laborist Party          NaN
# 19                                           NaN          NaN
# 25     Progressive Party,Social Democratic Party          NaN
# ...                                          ...          ...
# 65147                 Round TableâFree Georgia          NaN
# 65148                                        NaN          NaN
# 65150                                        NaN          NaN
# 65152               Freedom Union,Civic Platform          NaN
# 65155                                        NaN          NaN
#
#                                                   labels
# 8                                                    NaN
# 10                                                   NaN
# 17                                                   NaN
# 19     Steeltown,Motown,Epic,Legacy,Sony,MJJ Productions
# 25                                                   NaN
# ...                                                  ...
# 65147                                                NaN
# 65148                                                NaN
# 65150                                                NaN
# 65152                                                NaN
# 65155                                                NaN
#
# [35746 rows x 24 columns]

# %%
df_all_names.to_csv('wikicrawler/wikicrawler_full.csv')

# %%
df_all_names.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35746 entries, 8 to 65155
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              35746 non-null  object
#  1   full_name         11569 non-null  object
#  2   born              35746 non-null  object
#  3   died              35746 non-null  object
#  4   citizenship       762 non-null    object
#  5   known_for         2677 non-null   object
#  6   schools           16706 non-null  object
#  7   degrees           4371 non-null   object
#  8   organizations     44 non-null     object
#  9   institutions      2272 non-null   object
#  10  spouses           5540 non-null   object
#  11  offspring         4631 non-null   object
#  12  parents           4298 non-null   object
#  13  relatives         4095 non-null   object
#  14  house             1431 non-null   object
#  15  title             152 non-null    object
#  16  doctoral_advisor  1906 non-null   object
#  17  fields            2316 non-null   object
#  18  positions         27815 non-null  object
#  19  occupation        6973 non-null   object
#  20  employer          146 non-null    object
#  21  political_party   20274 non-null  object
#  22  board_member      50 non-null     object
#  23  labels            13 non-null     object
# dtypes: object(24)
# memory usage: 6.8+ MB

# %%
df_no_gaps = df_all_names.drop_duplicates()
df_no_gaps
# Out:
#                           name                  full_name             born  \
# 0             Ãlvaro ObregÃ³n    Ãlvaro ObregÃ³n Salido       1880-02-19
# 8      Ãlvaro Lloreda Caicedo                        NaN       1903-10-15
# 11      Ãlvaro GÃ³mez Hurtado                        NaN       1919-05-08
# 28             Ãlcio Ãlvares                        NaN       1932-09-28
# 31     The Baron of Carondelet  ÃÃ±igo Cavero Lataillade       1929-08-01
# ...                        ...                        ...              ...
# 52488            Zurab Zhvania                        NaN  9 December 1963
# 52491            Zvi Griliches                        NaN       1930-09-12
# 52492       Zvonimir Äervenko                        NaN       1926-11-13
# 52494      Zygmunt Janiszewski                        NaN       1888-07-12
# 52495            Zyta Gilowska                        NaN       1949-07-07
#
#                    died  known_for  \
# 0          17 July 1928        NaN
# 8         10 April 1985        NaN
# 11     November 2, 1995        NaN
# 28      9 December 2016        NaN
# 31     25 December 2002        NaN
# ...                 ...        ...
# 52488   3 February 2005        NaN
# 52491   4 November 1999        NaN
# 52492  17 February 2001        NaN
# 52494    3 January 1920        NaN
# 52495      5 April 2016        NaN
#
#                                                  schools degrees  \
# 0                                                    NaN     NaN
# 8                                                    NaN     NaN
# 11                       Pontifical Xavierian University     NaN
# 28                                                   NaN     NaN
# 31     University of Deusto,Complutense University of...     NaN
# ...                                                  ...     ...
# 52488                           Tbilisi State University     NaN
# 52491                 University of Chicago,UCÂ Berkeley     NaN
# 52492                                                NaN     NaN
# 52494                                University of Paris     NaN
# 52495  Warsaw University,Maria Curie-Sklodowska Unive...     NaN
#
#                                     spouses  \
# 0                  MarÃ­a Tapia (1888-1971)
# 8                    Mercedes Caicedo Ortiz
# 11     Margarita Escobar LÃ³pez (1946-1995)
# 28                           Irene Ãlvares
# 31                                      NaN
# ...                                     ...
# 52488                                   NaN
# 52491                                   NaN
# 52492                                   NaN
# 52494                                   NaN
# 52495                                   NaN
#
#                                                offspring parents  \
# 0                                                    NaN     NaN
# 8                    Rodrigo Hern%C3%A1n Lloreda Caicedo     NaN
# 11     Mauricio GÃ³mez Escobar,Mercedes GÃ³mez Escoba...     NaN
# 28                                                   NaN     NaN
# 31                                                   NaN     NaN
# ...                                                  ...     ...
# 52488                                                NaN     NaN
# 52491                                                NaN     NaN
# 52492                                                NaN     NaN
# 52494                                                NaN     NaN
# 52495                                                NaN     NaN
#
#              relatives  title  \
# 0                  NaN    NaN
# 8                  NaN    NaN
# 11     Laureano GÃ³mez    NaN
# 28                 NaN    NaN
# 31                 NaN    NaN
# ...                ...    ...
# 52488              NaN    NaN
# 52491              NaN    NaN
# 52492              NaN    NaN
# 52494              NaN    NaN
# 52495              NaN    NaN
#
#                                                positions  \
# 0      46th President of Mexico,President of the Mexi...
# 8      Colombia Ambassador to Spain,Member of the Sen...
# 11     15th Colombia Ambassador to France,Colombia Am...
# 28     Minister of Defence of Brazil,Minister of Deve...
# 31     President of the Spanish Council of State,Mini...
# ...                                                  ...
# 52488  4th Prime Minister of Georgia,State Minister o...
# 52491                                                NaN
# 52492                                                NaN
# 52494                                                NaN
# 52495          Minister of Finance,Deputy Prime Minister
#
#                   occupation employer  political_party  board_member_of  \
# 0                        NaN      NaN              NaN              NaN
# 8                        NaN      NaN              NaN              NaN
# 11     Journalist,politician      NaN              NaN              NaN
# 28                       NaN      NaN              NaN              NaN
# 31                       NaN      NaN              NaN              NaN
# ...                      ...      ...              ...              ...
# 52488                    NaN      NaN              NaN              NaN
# 52491                    NaN      NaN              NaN              NaN
# 52492                    NaN      NaN              NaN              NaN
# 52494                    NaN      NaN              NaN              NaN
# 52495                    NaN      NaN              NaN              NaN
#
#        labels
# 0         NaN
# 8         NaN
# 11        NaN
# 28        NaN
# 31        NaN
# ...       ...
# 52488     NaN
# 52491     NaN
# 52492     NaN
# 52494     NaN
# 52495     NaN
#
# [27125 rows x 18 columns]

# %%
df_no_gaps.to_csv('wikicrawler/wikicrawler_born_died.csv')

# %%
df_degrees = df_no_gaps.dropna(subset=['schools', 'degrees'])

# %%
# Rearrange columns and sort on name
df_degrees = df_degrees[['name', 'full_name', 'born', 'occupation', 'schools', 'degrees', 'spouses', 'offspring']]
df_degrees.sort_values(by='name', ignore_index=True, inplace=True)
df_degrees
# Out:
#                             name                    full_name        born  \
# 0                 A. Andrew Hauk         Aloysius Andrew Hauk  1912-12-29
# 1              A. Bruce Bielaski                          NaN  1883-04-02
# 2                 A. J. McNamara           Abel John McNamara  1936-06-09
# 3             A. Mitchell Palmer    Alexander Mitchell Palmer  1872-05-04
# 4               A. P. Jayasuriya  Alexander Perera Jayasuriya  1901-11-01
# ...                          ...                          ...         ...
# 3478                Zakir Husain                          NaN  1897-02-08
# 3479          Zales Nelson Ecton                          NaN  1898-04-01
# 3480               Zhang Wentian                          NaN  1900-08-30
# 3481  Ä°hsan Sabri ÃaÄlayangil                          NaN        1908
# 3482               ÅÃ¼krÃ¼ Kaya                          NaN        1883
#
#      occupation                                            schools  \
# 0           NaN  Regis University,Columbus School of Law,Yale L...
# 1           NaN                       George Washington University
# 2           NaN  Louisiana State University,Loyola University N...
# 3           NaN                                 Swarthmore College
# 4      Advocate  Sri Sumangala College,Panadura,Royal College, ...
# ...         ...                                                ...
# 3478        NaN  Mohammedan Anglo-Oriental College Aligarh,Univ...
# 3479        NaN     Montana State University,University of Chicago
# 3480        NaN  University of California, Berkeley,Moscow Sun ...
# 3481        NaN          Ä°stanbul University,Istanbul High School
# 3482        NaN  Galatasaray High School,Istanbul University,Un...
#
#                             degrees           spouses offspring
# 0                 A.B.,J.S.D.,LL.B.               NaN       NaN
# 1                               LLB               NaN       NaN
# 2                         J.D.,B.S.               NaN       NaN
# 3                                BA    Roberta Dixon        NaN
# 4                          Panadura               NaN       NaN
# ...                             ...               ...       ...
# 3478                         PhD,MA  Shah Jahan Begum         2
# 3479                         BS,LLB       Vera Harris         2
# 3480  Moscow Sun Yat-sen University               NaN       NaN
# 3481           Istanbul High School               NaN       NaN
# 3482            Istanbul University               NaN       NaN
#
# [3483 rows x 8 columns]

# %%
df_degrees.set_index('name', drop=True, inplace=True)
df_degrees
# Out:
#                                               full_name        born  \
# name
# A. Andrew Hauk                     Aloysius Andrew Hauk  1912-12-29
# A. Bruce Bielaski                                   NaN  1883-04-02
# A. J. McNamara                       Abel John McNamara  1936-06-09
# A. Mitchell Palmer            Alexander Mitchell Palmer  1872-05-04
# A. P. Jayasuriya            Alexander Perera Jayasuriya  1901-11-01
# ...                                                 ...         ...
# Zakir Husain                                        NaN  1897-02-08
# Zales Nelson Ecton                                  NaN  1898-04-01
# Zhang Wentian                                       NaN  1900-08-30
# Ä°hsan Sabri ÃaÄlayangil                          NaN        1908
# ÅÃ¼krÃ¼ Kaya                                       NaN        1883
#
#                            occupation  \
# name
# A. Andrew Hauk                    NaN
# A. Bruce Bielaski                 NaN
# A. J. McNamara                    NaN
# A. Mitchell Palmer                NaN
# A. P. Jayasuriya             Advocate
# ...                               ...
# Zakir Husain                      NaN
# Zales Nelson Ecton                NaN
# Zhang Wentian                     NaN
# Ä°hsan Sabri ÃaÄlayangil        NaN
# ÅÃ¼krÃ¼ Kaya                     NaN
#
#                                                                       schools  \
# name
# A. Andrew Hauk              Regis University,Columbus School of Law,Yale L...
# A. Bruce Bielaski                                George Washington University
# A. J. McNamara              Louisiana State University,Loyola University N...
# A. Mitchell Palmer                                         Swarthmore College
# A. P. Jayasuriya            Sri Sumangala College,Panadura,Royal College, ...
# ...                                                                       ...
# Zakir Husain                Mohammedan Anglo-Oriental College Aligarh,Univ...
# Zales Nelson Ecton             Montana State University,University of Chicago
# Zhang Wentian               University of California, Berkeley,Moscow Sun ...
# Ä°hsan Sabri ÃaÄlayangil          Ä°stanbul University,Istanbul High School
# ÅÃ¼krÃ¼ Kaya               Galatasaray High School,Istanbul University,Un...
#
#                                                   degrees           spouses  \
# name
# A. Andrew Hauk                          A.B.,J.S.D.,LL.B.               NaN
# A. Bruce Bielaski                                     LLB               NaN
# A. J. McNamara                                  J.D.,B.S.               NaN
# A. Mitchell Palmer                                     BA    Roberta Dixon
# A. P. Jayasuriya                                 Panadura               NaN
# ...                                                   ...               ...
# Zakir Husain                                       PhD,MA  Shah Jahan Begum
# Zales Nelson Ecton                                 BS,LLB       Vera Harris
# Zhang Wentian               Moscow Sun Yat-sen University               NaN
# Ä°hsan Sabri ÃaÄlayangil           Istanbul High School               NaN
# ÅÃ¼krÃ¼ Kaya                         Istanbul University               NaN
#
#                            offspring
# name
# A. Andrew Hauk                   NaN
# A. Bruce Bielaski                NaN
# A. J. McNamara                   NaN
# A. Mitchell Palmer               NaN
# A. P. Jayasuriya                 NaN
# ...                              ...
# Zakir Husain                       2
# Zales Nelson Ecton                 2
# Zhang Wentian                    NaN
# Ä°hsan Sabri ÃaÄlayangil       NaN
# ÅÃ¼krÃ¼ Kaya                    NaN
#
# [3483 rows x 7 columns]

# %%
# Keep only complete records
df_all_fields = df.dropna(how='any')

# %%
def date_converter(x):
    if x:
        if '-' in x:
            updated = dt.strptime(str(x), '%Y-%m-%d %H:%M:%S')
        elif '/' in x:
            updated = dt.strptime(str(x), '%m/%d/%Y %H:%M:%S')
        else:
            return None
        print(updated)
        return updated.strftme('%Y-%m-%d')        
    else:
        return None

# %%
# df_degrees['DOB'] = np.vectorize(date_converter)(df_degrees['DOB'])
df_degrees['born'] = pd.to_datetime(df_degrees.born)
df_degrees['born'] = df_degrees['born'].dt.strftime('%Y-%m-%d')
df_degrees
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2186         try:
# -> 2187             values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
#    2188             # If tzaware, these values represent unix timestamps, so we
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24168/3527484894.py in <module>
#       1 # df_degrees['DOB'] = np.vectorize(date_converter)(df_degrees['DOB'])
# ----> 2 df_degrees['born'] = pd.to_datetime(df_degrees.born)
#       3 df_degrees['born'] = df_degrees['born'].dt.strftime('%Y-%m-%d')
#       4 df_degrees
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     885             result = arg.map(cache_array)
#     886         else:
# --> 887             values = convert_listlike(arg._values, format)
#     888             result = arg._constructor(values, index=arg.index, name=arg.name)
#     889     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     399     assert format is None or infer_datetime_format
#     400     utc = tz == "utc"
# --> 401     result, tz_parsed = objects_to_datetime64ns(
#     402         arg,
#     403         dayfirst=dayfirst,
#
# ~\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2191             return values.view("i8"), tz_parsed
#    2192         except (ValueError, TypeError):
# -> 2193             raise err
#    2194
#    2195     if tz_parsed is not None:
#
# ~\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2173     order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2174     try:
# -> 2175         result, tz_parsed = tslib.array_to_datetime(
#    2176             data.ravel("K"),
#    2177             errors=errors,
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\tslib.pyx in pandas._libs.tslib._array_to_datetime_object()
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\tslib.pyx in pandas._libs.tslib._array_to_datetime_object()
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~\Anaconda3\lib\site-packages\dateutil\parser\_parser.py in parse(timestr, parserinfo, **kwargs)
#    1366         return parser(parserinfo).parse(timestr, **kwargs)
#    1367     else:
# -> 1368         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1369
#    1370
#
# ~\Anaconda3\lib\site-packages\dateutil\parser\_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     644
#     645         if len(res) == 0:
# --> 646             raise ParserError("String does not contain a date: %s", timestr)
#     647
#     648         try:
#
# ParserError: String does not contain a date: ,

# %%
df_degrees.to_csv('wikicrawler/people_data_full.csv')

# %% [markdown]
# ## Rhodes Scholars

# %%
rhodes_df = pd.read_csv('rhodescholars/rhodes_data.csv')
rhodes_df

# %%
df_occupations = rhodes_df.merge(df_no_gaps, on='name', how='outer')
df_occupations

# %%
df_occupations.to_csv('wikicrawler/merged_occupations.csv')
