# %% [markdown]
# <h1 align='center'>MSDE 692</h1>

# %% [markdown]
# [Function Definitions](#Function-Definitions)
#
# [Clean CSV Input File](#Clean-CSV-Input-File)
#
# [Data Cleaning](#Data-Cleaning)

# %%
import os
import pandas as pd
import neo4j
import numpy as np

from datetime import datetime as dt
from csv import DictReader, writer

# %% [markdown]
# ## Function Definitions

# %%
def people_pruner(my_file):
    my_list = []

    with open(my_file, 'r') as f:
        reader = DictReader(f, fieldnames='person')

        for row in reader:
            if [row['p']] not in my_list:
                my_list.append([row['p']])
            else:
                print(f"Duplicate person: {row['p']}")
    
    return my_list

# %%
def csv_writer(my_file, my_list):

    with open(my_file, 'w', newline='') as outfile:

        # using csv.writer method from CSV package
        csv_writer = writer(outfile)

        for row in my_list:
            csv_writer.writerow(row)

# %% [markdown]
# ## Clean CSV Input File

# %%
people_list = people_pruner('wikicrawler/people_temp.csv')
# Out:
# Duplicate person: Sophie_Gr%C3%A9goire_Trudeau
# Duplicate person: Lynne_Cheney
# Duplicate person: Marilyn_Quayle
# Duplicate person: Susan_Weber_(historian)
# Duplicate person: Nancy_Kissinger
# Duplicate person: Hillary_Rodham
# Duplicate person: Doug_Emhoff
# Duplicate person: Priscilla_Chan
# Duplicate person: MacKenzie_Scott
# Duplicate person: Ashley_Estes_Kavanaugh
# Duplicate person: Ginni_Thomas
# Duplicate person: George_Akerlof
# Duplicate person: Andrea_Mitchell
# Duplicate person: Edward_Sugden_(methodist)
# Duplicate person: Gertrude_Schoepperle
# Duplicate person: Laura_Hibbard_Loomis
# Duplicate person: Mary_Herring
# Duplicate person: Edna_Manley
# Duplicate person: Ida_Gordon
# Duplicate person: Editha_Olga_Bailey
# Duplicate person: Evelyn_Lett
# Duplicate person: Virginia_Durr
# Duplicate person: Fay_Wray
# Duplicate person: Norah_Michener
# Duplicate person: index.php?title=Helen_Hill_Miller&action=edit&redlink=1
# Duplicate person: Marian_Dale_Scott
# Duplicate person: Harriet_Mayor_Fulbright
# Duplicate person: Clarita_Tiefenbacher
# Duplicate person: Myrna_Loy
# Duplicate person: Mary_Gluckman
# Duplicate person: Elspeth_Rostow
# Duplicate person: Alison_Burton
# Duplicate person: Louise_Allbritton
# Duplicate person: Susan_McLane
# Duplicate person: Geills_Turner
# Duplicate person: Sondra_Gotlieb
# Duplicate person: index.php?title=Danielle_L._Gardner&action=edit&redlink=1
# Duplicate person: Catherine_Hall
# Duplicate person: Sally_Brophy
# Duplicate person: Deborah_McCawley
# Duplicate person: Meg_Whitman
# Duplicate person: Mary_M._Ourisman
# Duplicate person: Dagmar_Braun_Celeste
# Duplicate person: Isher_Judge_Ahluwalia
# Duplicate person: Utsa_Patnaik
# Duplicate person: Michelle_Gordon_(judge)
# Duplicate person: Arlene_Perly_Rae
# Duplicate person: Deborah_Fallows
# Duplicate person: Kathy_Lette
# Duplicate person: Selma_Botman
# Duplicate person: Clayton_Spencer
# Duplicate person: Jef_McAllister
# Duplicate person: Elizabeth_Esty
# Duplicate person: Tom_Adkins
# Duplicate person: Sheryl_WuDunn
# Duplicate person: Wendy_Vitter
# Duplicate person: Tom_Conroy
# Duplicate person: Ali_Wentworth
# Duplicate person: Samantha_Nutt
# Duplicate person: Melanie_Verwoerd
# Duplicate person: Rajdeep_Sardesai
# Duplicate person: Alan_Thomas_(philosopher)
# Duplicate person: Ann_M._O%27Leary
# Duplicate person: Sarah_Sze
# Duplicate person: Lia_Epperson
# Duplicate person: Jenny_Salesa
# Duplicate person: Sara_Bronin
# Duplicate person: Hannah_Van_Buren
# Duplicate person: Anna_Harrison
# Duplicate person: Letitia_Christian_Tyler
# Duplicate person: Julia_Gardiner_Tyler
# Duplicate person: Elizabeth_Monroe
# Duplicate person: Louisa_Adams
# Duplicate person: Dolley_Madison
# Duplicate person: Martha_Washington
# Duplicate person: Rachel_Jackson
# Duplicate person: Jane_Pierce
# Duplicate person: Abigail_Adams
# Duplicate person: Sarah_Childress_Polk
# Duplicate person: Abigail_Fillmore
# Duplicate person: Caroline_C._Fillmore
# Duplicate person: Martha_Jefferson
# Duplicate person: Lucy_Ware_Webb
# Duplicate person: Caroline_Harrison
# Duplicate person: Mary_Dimmick_Harrison
# Duplicate person: Frances_Cleveland
# Duplicate person: Lucretia_Garfield
# Duplicate person: Nell_Arthur
# Duplicate person: Ida_Saxton_McKinley
# Duplicate person: Helen_Herron_Taft
# Duplicate person: Florence_Kling
# Duplicate person: Grace_Coolidge
# Duplicate person: Lou_Henry_Hoover
# Duplicate person: Eleanor_Roosevelt
# Duplicate person: Jacqueline_Bouvier
# Duplicate person: Mamie_Eisenhower
# Duplicate person: Bess_Wallace
# Duplicate person: Betty_Ford
# Duplicate person: Pat_Nixon
# Duplicate person: Barbara_Bush
# Duplicate person: Jane_Wyman
# Duplicate person: Nancy_Reagan
# Duplicate person: Rosalynn_Carter
# Duplicate person: Lady_Bird_Johnson
# Duplicate person: George_W._Bush
# Duplicate person: Neilia_Hunter_Biden
# Duplicate person: Jill_Biden
# Duplicate person: Kerstin_Emhoff
# Duplicate person: Kamala_Harris
# Duplicate person: Justin_Trudeau
# Duplicate person: Dick_Cheney
# Duplicate person: Henry_Kissinger
# Duplicate person: Dan_Quayle
# Duplicate person: Jeff_Bezos
# Duplicate person: Mark_Zuckerberg
# Duplicate person: Brett_Kavanaugh
# Duplicate person: Vladimir_Putin
# Duplicate person: Bill_Gates
# Duplicate person: Xi_Jinping
# Duplicate person: Clarence_Thomas
# Duplicate person: Janet_Yellen
# Duplicate person: Alan_Greenspan
# Duplicate person: Edmund_Herring
# Duplicate person: Norman_Manley
# Duplicate person: John_Monk_Saunders
# Duplicate person: Robert_Riskin
# Duplicate person: Sherwood_Lett
# Duplicate person: Clifford_Durr
# Duplicate person: Charles_Collingwood_(journalist)
# Duplicate person: F._R._Scott
# Duplicate person: John_Turner
# Duplicate person: Bob_Hawke
# Duplicate person: George_Goodman
# Duplicate person: Pete_Dawkins
# Duplicate person: Arthur_Hornblow_Jr.
# Duplicate person: Gene_Markey
# Duplicate person: Howland_H._Sargeant
# Duplicate person: Montek_Singh_Ahluwalia
# Duplicate person: Griffith_R._Harsh
# Duplicate person: Kenneth_Hayne
# Duplicate person: Prabhat_Patnaik
# Duplicate person: Dick_Celeste
# Duplicate person: Kim_Williams_(media_executive)
# Duplicate person: Geoffrey_Robertson
# Duplicate person: Nicholas_D._Kristof
# Duplicate person: Ash_Carter
# Duplicate person: Tony_Abbott
# Duplicate person: Sarah_Sewall
# Duplicate person: Malcolm_Turnbull
# Duplicate person: Sagarika_Ghose
# Duplicate person: Eric_Greitens
# Duplicate person: Daniel_Parke_Custis
# Duplicate person: George_Washington
# Duplicate person: John_Adams
# Duplicate person: Pete_Buttigieg
# Duplicate person: William_Henry_Harrison
# Duplicate person: John_Tyler
# Duplicate person: Thomas_Jefferson
# Duplicate person: Andrew_Jackson
# Duplicate person: James_Madison
# Duplicate person: James_Monroe
# Duplicate person: Zachary_Taylor
# Duplicate person: James_K._Polk
# Duplicate person: John_Quincy_Adams
# Duplicate person: Millard_Fillmore
# Duplicate person: Franklin_Pierce
# Duplicate person: Abraham_Lincoln
# Duplicate person: Ulysses_S._Grant
# Duplicate person: Andrew_Johnson
# Duplicate person: James_A._Garfield
# Duplicate person: Chester_A._Arthur
# Duplicate person: Benjamin_Harrison
# Duplicate person: Grover_Cleveland
# Duplicate person: Thomas_J._Preston,_Jr.
# Duplicate person: William_McKinley
# Duplicate person: Warren_G._Harding
# Duplicate person: William_Howard_Taft
# Duplicate person: Herbert_Hoover
# Duplicate person: Calvin_Coolidge
# Duplicate person: Lyndon_B._Johnson
# Duplicate person: Theodore_Roosevelt
# Duplicate person: Woodrow_Wilson
# Duplicate person: Harry_S._Truman
# Duplicate person: Franklin_D._Roosevelt
# Duplicate person: Dwight_D._Eisenhower
# Duplicate person: Gerald_Ford
# Duplicate person: George_H._W._Bush
# Duplicate person: Richard_Nixon
# Duplicate person: John_F._Kennedy
# Duplicate person: Assassination_of_John_F._Kennedy
# Duplicate person: Aristotle_Onassis
# Duplicate person: Donald_Trump
# Duplicate person: Joe_Biden
# Duplicate person: Barack_Obama
# Duplicate person: Ronald_Reagan
# Duplicate person: Pierre_Trudeau
# Duplicate person: William_Jefferson_Blythe_Jr.
# Duplicate person: Roger_Clinton_Sr.
# Duplicate person: Jeff_Dwire
# Duplicate person: Hugh_Rodham_(born_1911)
# Duplicate person: Dorothy_Howell_Rodham
# Duplicate person: Virginia_Clinton_Kelley
# Duplicate person: Shyamala_Gopalan
# Duplicate person: Donald_J._Harris
# Duplicate person: Qi_Xin
# Duplicate person: Margaret_Trudeau
# Duplicate person: Robert_F._Burford
# Duplicate person: Elizabeth_Bonython
# Duplicate person: Betty_Judge
# Duplicate person: Lois_Rice
# Duplicate person: George_Edwards_(actor)
# Duplicate person: Emmett_J._Rice
# Duplicate person: Alfred_B._Fitt
# Duplicate person: Frank_Sinatra
# Duplicate person: Andr%C3%A9_Previn
# Duplicate person: Louise_Lasser
# Duplicate person: Soon-Yi_Previn
# Duplicate person: Susanna_Boylston
# Duplicate person: Hannah_Simpson_Grant
# Duplicate person: Jesse_Root_Grant
# Duplicate person: Theodore_Roosevelt_Sr.
# Duplicate person: Martha_Bulloch_Roosevelt
# Duplicate person: Louise_Taft
# Duplicate person: Sara_Roosevelt
# Duplicate person: James_Roosevelt_I
# Duplicate person: Hannah_Milhous_Nixon
# Duplicate person: Francis_A._Nixon
# Duplicate person: Dorothy_Ayer_Gardner_Ford
# Duplicate person: Nelle_Wilson_Reagan
# Duplicate person: Lillian_Gordy_Carter
# Duplicate person: Leslie_Lynch_King_Sr.
# Duplicate person: Gerald_Rudolff_Ford
# Duplicate person: Ann_Dunham
# Duplicate person: Mary_Anne_MacLeod_Trump
# Duplicate person: Barack_Obama_Sr.
# Duplicate person: Lolo_Soetoro
# Duplicate person: Fred_Trump
# Duplicate person: Elaine_Carroll
# Duplicate person: Kirill_Shamalov
# Duplicate person: Jorrit_Faassen
# Duplicate person: Marc_Mezvinsky
# Duplicate person: Beverley_Manley
# Duplicate person: William_Stephens_Smith
# Duplicate person: Thomas_Mann_Randolph_Jr.
# Duplicate person: Angelica_Singleton_Van_Buren
# Duplicate person: Jefferson_Davis
# Duplicate person: William_Wallace_Smith_Bliss
# Duplicate person: David_T._Patterson
# Duplicate person: Mary_Harlan_Lincoln
# Duplicate person: Helen_Newell_Garfield
# Duplicate person: Ida_Marie_Honor%C3%A9
# Duplicate person: Nicholas_Longworth
# Duplicate person: Eleanor_Butler_Roosevelt
# Duplicate person: Chuck_Robb
# Duplicate person: Curtis_Bean_Dall
# Duplicate person: Clarence_John_Boettiger
# Duplicate person: Ethel_du_Pont
# Duplicate person: Francis_Bowes_Sayre_Sr.
# Duplicate person: William_Gibbs_McAdoo
# Duplicate person: Betsey_Cushing_Roosevelt_Whitney
# Duplicate person: Faye_Emerson
# Duplicate person: Edward_F._Cox
# Duplicate person: Edwin_Schlossberg
# Duplicate person: Carolyn_Bessette-Kennedy
# Duplicate person: David_Eisenhower
# Duplicate person: David_Sills_(judge)
# Duplicate person: Sharon_Bush
# Duplicate person: Bobby_Koch
# Duplicate person: Paul_Grilley
# Duplicate person: Lara_Trump
# Duplicate person: Jared_Kushner
# Duplicate person: Vanessa_Haydon
# Duplicate person: Howard_Krein
# Duplicate person: Jacqueline_Kennedy_Onassis
# Duplicate person: Anne_Gorsuch_Burford
# Duplicate person: Woody_Allen
# Duplicate person: Liz_Cheney
# Duplicate person: Katerina_Tikhonova
# Duplicate person: Chelsea_Clinton
# Duplicate person: Maria_Vorontsova
# Duplicate person: Robert_Todd_Lincoln
# Duplicate person: Abraham_Van_Buren
# Duplicate person: Martha_Jefferson_Randolph
# Duplicate person: Sarah_Knox_Taylor
# Duplicate person: Frederick_Dent_Grant
# Duplicate person: Theodore_Roosevelt_Jr.
# Duplicate person: Alice_Roosevelt_Longworth
# Duplicate person: Franklin_D._Roosevelt_Jr.
# Duplicate person: Eleanor_Wilson_McAdoo
# Duplicate person: Jessie_Woodrow_Wilson_Sayre
# Duplicate person: Lynda_Bird_Johnson_Robb
# Duplicate person: Anna_Roosevelt_Halsted
# Duplicate person: Caroline_Kennedy
# Duplicate person: Elliott_Roosevelt_(general)
# Duplicate person: Julie_Nixon_Eisenhower
# Duplicate person: Maureen_Reagan
# Duplicate person: Jeb_Bush
# Duplicate person: John_F._Kennedy_Jr.
# Duplicate person: Patti_Davis
# Duplicate person: Tricia_Nixon_Cox
# Duplicate person: James_Roosevelt
# Duplicate person: Eric_Trump
# Duplicate person: Dorothy_Bush_Koch
# Duplicate person: Donald_Trump_Jr.
# Duplicate person: Ivanka_Trump
# Duplicate person: Anna_Hall_Roosevelt
# Duplicate person: Janet_Lee_Bouvier
# Duplicate person: Elliott_Roosevelt_(socialite)
# Duplicate person: John_Vernou_Bouvier_III
# Duplicate person: Family_of_Barack_Obama#Fraser_C._Robinson_III_(1935–1991)
# Duplicate person: Elizabeth_Christ_Trump
# Duplicate person: Madelyn_Dunham
# Duplicate person: Frederick_Trump
# Duplicate person: Stanley_Armour_Dunham
# Duplicate person: Pierre_Trudeau
# Duplicate person: Margaret_Trudeau
# Duplicate person: James_C._Quayle
# Duplicate person: William_Jefferson_Blythe_Jr.
# Duplicate person: Virginia_Clinton_Kelley
# Duplicate person: Donald_J._Harris
# Duplicate person: Shyamala_Gopalan
# Duplicate person: Anne_Gorsuch_Burford
# Duplicate person: Clarence_Hale
# Duplicate person: Frederick_George_Scott
# Duplicate person: John_Maynard_Harlan
# Duplicate person: Ralph_Connor
# Duplicate person: August_von_Trott_zu_Solz
# Duplicate person: William_Morton_(Manitoba_politician)
# Duplicate person: John_Bradfield_(engineer)
# Duplicate person: Phyllis_Ross
# Duplicate person: Kenneth_Bailey_(lawyer)
# Duplicate person: Keith_Wilson_(South_Australian_politician)
# Duplicate person: Elizabeth_Bonython
# Duplicate person: Lyle_Boren
# Duplicate person: Peter_Heydon
# Duplicate person: Hsue-Chu_Tsien
# Duplicate person: Betty_Binns_Fletcher
# Duplicate person: Kim_Beazley_Sr.
# Duplicate person: Betty_Judge
# Duplicate person: John_Crosbie
# Duplicate person: Emmett_J._Rice
# Duplicate person: Lois_Rice
# Duplicate person: Blair_Clark
# Duplicate person: Gil_Garcetti
# Duplicate person: Roger_B._Porter
# Duplicate person: Mia_Farrow
# Duplicate person: Woody_Allen
# Duplicate person: Abraham_Van_Buren_(I)
# Duplicate person: Benjamin_Harrison_V
# Duplicate person: John_Tyler_Sr.
# Duplicate person: John_Adams
# Duplicate person: Abigail_Adams
# Duplicate person: James_Madison_Sr.
# Duplicate person: Augustine_Washington
# Duplicate person: Mary_Ball_Washington
# Duplicate person: Benjamin_Pierce_(governor)
# Duplicate person: John_Adams_Sr.
# Duplicate person: Susanna_Boylston
# Duplicate person: Samuel_Polk
# Duplicate person: Nathaniel_Fillmore
# Duplicate person: John_Scott_Harrison
# Duplicate person: Richard_Falley_Cleveland
# Duplicate person: William_McKinley_Sr.
# Duplicate person: Alphonso_Taft
# Duplicate person: Louise_Taft
# Duplicate person: George_Tryon_Harding
# Duplicate person: John_Calvin_Coolidge_Sr.
# Duplicate person: James_Roosevelt_I
# Duplicate person: Sara_Roosevelt
# Duplicate person: John_Anderson_Truman
# Duplicate person: Martha_Ellen_Young
# Duplicate person: Leslie_Lynch_King_Sr.
# Duplicate person: Dorothy_Ayer_Gardner_Ford
# Duplicate person: Francis_A._Nixon
# Duplicate person: Hannah_Milhous_Nixon
# Duplicate person: Jack_Reagan
# Duplicate person: Nelle_Wilson_Reagan
# Duplicate person: James_Earl_Carter_Sr.
# Duplicate person: Lillian_Gordy_Carter
# Duplicate person: Samuel_Ealy_Johnson_Jr.
# Duplicate person: Tom_Hughes_(Australian_politician)
# Duplicate person: Dilip_Sardesai
# Duplicate person: John_Dandridge
# Duplicate person: Frances_Jones_(colonist)
# Duplicate person: John_Cleves_Symmes
# Duplicate person: John_Donelson
# Duplicate person: Jesse_Appleton
# Duplicate person: Robert_Smith_Todd
# Duplicate person: John_Witherspoon_Scott
# Duplicate person: Charles_Carow
# Duplicate person: Elliott_Roosevelt_(socialite)
# Duplicate person: Anna_Hall_Roosevelt
# Duplicate person: Marvin_Pierce
# Duplicate person: John_Vernou_Bouvier_III
# Duplicate person: Janet_Lee_Bouvier
# Duplicate person: Family_of_Barack_Obama#Fraser_C._Robinson_III_(1935–1991)
# Duplicate person: Marian_Shields_Robinson
# Duplicate person: Edith_Luckett_Davis
# Duplicate person: James_Sinclair_(politician)
# Duplicate person: P._V._Gopalan
# Duplicate person: Charles-%C3%89mile_Trudeau
# Duplicate person: John_Marshall_Harlan
# Duplicate person: Malvina_Shanklin_Harlan
# Duplicate person: William_Clark_(judge)
# Duplicate person: Chesley_Crosbie
# Duplicate person: Ambrose_Madison
# Duplicate person: Benjamin_Harrison_IV
# Duplicate person: James_Stephens_Bulloch
# Duplicate person: Cornelius_Roosevelt
# Duplicate person: Samuel_Ealy_Johnson_Sr.
# Duplicate person: Isaac_Roosevelt_(businessman)
# Duplicate person: Warren_Delano_Jr.
# Duplicate person: Charles_Henry_King
# Duplicate person: Family_of_Barack_Obama#Hussein_Onyango_Obama
# Duplicate person: Family_of_Barack_Obama#Habiba_Akumu_Obama
# Duplicate person: Frederick_Trump
# Duplicate person: Elizabeth_Christ_Trump
# Duplicate person: Stanley_Armour_Dunham
# Duplicate person: Madelyn_Dunham
# Duplicate person: George_W._Bush
# Duplicate person: Laura_Bush
# Duplicate person: Dan_Quayle
# Duplicate person: Marilyn_Quayle
# Duplicate person: Dick_Cheney
# Duplicate person: Lynne_Cheney
# Duplicate person: Robert_Reich
# Duplicate person: George_Soros
# Duplicate person: Philip_Le_Couteur
# Duplicate person: Xi_Jinping
# Duplicate person: Peng_Liyuan
# Duplicate person: Susan_Weber_Soros
# Duplicate person: Bill_Clinton
# Duplicate person: Hillary_Clinton
# Duplicate person: Norman_Manley
# Duplicate person: Edna_Manley
# Duplicate person: J._King_Gordon
# Duplicate person: Otto_Lang
# Duplicate person: Girish_Karnad
# Duplicate person: Daniel_Parke_Custis
# Duplicate person: Martha_Dandridge
# Duplicate person: George_Washington
# Duplicate person: Kim_Beazley
# Duplicate person: David_Hatendi
# Duplicate person: Sally_Hemings
# Duplicate person: Thomas_Jefferson
# Duplicate person: Martha_Wayles_Skelton_Jefferson
# Duplicate person: Martin_Van_Buren
# Duplicate person: Hannah_Van_Buren
# Duplicate person: John_Tyler
# Duplicate person: Julia_Gardiner_Tyler
# Duplicate person: Zachary_Taylor
# Duplicate person: Margaret_Taylor
# Duplicate person: John_Quincy_Adams
# Duplicate person: Louisa_Adams
# Duplicate person: Millard_Fillmore
# Duplicate person: Abigail_Powers
# Duplicate person: Abraham_Lincoln
# Duplicate person: Mary_Todd_Lincoln
# Duplicate person: Abigail_Fillmore
# Duplicate person: Rutherford_B._Hayes
# Duplicate person: Lucy_Webb_Hayes
# Duplicate person: Ulysses_S._Grant
# Duplicate person: Julia_Grant
# Duplicate person: Grover_Cleveland
# Duplicate person: Frances_Cleveland
# Duplicate person: Frances_Folsom
# Duplicate person: Benjamin_Harrison
# Duplicate person: Mary_Dimmick_Harrison
# Duplicate person: Warren_G._Harding
# Duplicate person: Nan_Britton
# Duplicate person: Herbert_Clark_Hoover
# Duplicate person: Lou_Henry_Hoover
# Duplicate person: William_Howard_Taft
# Duplicate person: Helen_Herron_Taft
# Duplicate person: Theodore_Roosevelt
# Duplicate person: Alice_Hathaway_Lee_Roosevelt
# Duplicate person: Edith_Roosevelt
# Duplicate person: Lyndon_B._Johnson
# Duplicate person: Lady_Bird_Johnson
# Duplicate person: Calvin_Coolidge
# Duplicate person: Grace_Coolidge
# Duplicate person: Woodrow_Wilson
# Duplicate person: Ellen_Axson_Wilson
# Duplicate person: Franklin_D._Roosevelt
# Duplicate person: Eleanor_Roosevelt
# Duplicate person: John_F._Kennedy
# Duplicate person: Jacqueline_Kennedy_Onassis
# Duplicate person: Richard_Nixon
# Duplicate person: Pat_Nixon
# Duplicate person: Dwight_D._Eisenhower
# Duplicate person: Mamie_Eisenhower
# Duplicate person: Jacqueline_Kennedy
# Duplicate person: Harry_S._Truman
# Duplicate person: Bess_Truman
# Duplicate person: Gerald_Ford
# Duplicate person: Betty_Ford
# Duplicate person: George_H._W._Bush
# Duplicate person: Barbara_Bush
# Duplicate person: Donald_Trump
# Duplicate person: Marla_Maples
# Duplicate person: Ivana_Trump
# Duplicate person: Joe_Biden
# Duplicate person: Jill_Biden
# Duplicate person: Neilia_Hunter_Biden
# Duplicate person: John_Eisenhower
# Duplicate person: Theodore_Roosevelt_Sr.
# Duplicate person: Martha_Bulloch_Roosevelt
# Duplicate person: Doug_Emhoff
# Duplicate person: Kerstin_Emhoff
# Duplicate person: Robert_Riskin
# Duplicate person: Fay_Wray
# Duplicate person: James_Madison
# Duplicate person: Hugh_Rodham_(born_1911)
# Duplicate person: Dorothy_Howell_Rodham
# Duplicate person: Roger_Clinton_Sr.
# Duplicate person: Fred_Trump
# Duplicate person: Mary_Anne_MacLeod_Trump
# Duplicate person: Gerald_Rudolff_Ford
# Duplicate person: Lolo_Soetoro
# Duplicate person: Ann_Dunham
# Duplicate person: Lyon_Gardiner_Tyler
# Duplicate person: Thomas_Mann_Randolph_Jr.
# Duplicate person: Martha_Jefferson_Randolph
# Duplicate person: Robert_Todd_Lincoln
# Duplicate person: Chester_Alan_Arthur_II
# Duplicate person: Robert_A._Taft
# Duplicate person: Theodore_Roosevelt_Jr.
# Duplicate person: Charles_Phelps_Taft_II
# Duplicate person: Kermit_Roosevelt
# Duplicate person: Francis_Bowes_Sayre_Sr.
# Duplicate person: Jessie_Woodrow_Wilson_Sayre
# Duplicate person: Anna_Roosevelt_Halsted
# Duplicate person: Curtis_Bean_Dall
# Duplicate person: Franklin_Delano_Roosevelt_Jr.
# Duplicate person: Ethel_du_Pont
# Duplicate person: Clarence_John_Boettiger
# Duplicate person: Caroline_Kennedy
# Duplicate person: Edwin_Schlossberg
# Duplicate person: David_Eisenhower
# Duplicate person: Julie_Nixon_Eisenhower
# Duplicate person: James_Roosevelt
# Duplicate person: Edward_F._Cox
# Duplicate person: Tricia_Nixon_Cox
# Duplicate person: Neil_Bush
# Duplicate person: Sharon_Bush
# Duplicate person: Betsey_Cushing_Roosevelt_Whitney
# Duplicate person: John_Hay_Whitney
# Duplicate person: Liz_Cheney
# Duplicate person: Mary_Cheney
# Duplicate person: Sam_Reich
# Duplicate person: Ben_Quayle
# Duplicate person: Jonathan_Soros
# Duplicate person: Alexander_Soros
# Duplicate person: Chelsea_Clinton
# Duplicate person: George_Le_Couteur
# Duplicate person: Order_of_the_British_Empire
# Duplicate person: Douglas_Manley
# Duplicate person: Michael_Manley
# Duplicate person: Peter_Hamilton_Bailey
# Duplicate person: Alex_Campbell_(politician)
# Duplicate person: Galt_MacDermot
# Duplicate person: Andrew_P._Miller
# Duplicate person: Peter_Dale_Scott
# Duplicate person: Charles_Gordon_(journalist)
# Duplicate person: Alison_Gordon
# Duplicate person: John_Watt_(physicist)
# Duplicate person: Tim_Reid_(politician)
# Duplicate person: Margaret_Trudeau
# Duplicate person: Susan_Coyne
# Duplicate person: Andrew_Coyne
# Duplicate person: David_Rusk
# Duplicate person: Richard_Rusk
# Duplicate person: John_Templeton_Jr.
# Duplicate person: Michael_Ignatieff
# Duplicate person: Nancy_White_(field_hockey)
# Duplicate person: Barbara_Baker_(judge)
# Duplicate person: Simon_Cawkwell
# Duplicate person: John_Katzenbach
# Duplicate person: Margaret_Cezair-Thompson
# Duplicate person: Pico_Iyer
# Duplicate person: Anthony_L._Gardner
# Duplicate person: Amanda_Lang
# Duplicate person: Julia_Marciari-Alexander
# Duplicate person: John_Sarbanes
# Duplicate person: Raghu_Karnad
# Duplicate person: Dan_Boren
# Duplicate person: Seth_Magaziner
# Duplicate person: Rob_Porter
# Duplicate person: Xandru_Grech
# Duplicate person: Wikipedia:Citation_needed
# Duplicate person: Hannah_Beazley
# Duplicate person: Nyasha_Hatendi
# Duplicate person: Abraham_Van_Buren
# Duplicate person: John_Van_Buren
# Duplicate person: John_Scott_Harrison
# Duplicate person: Letitia_Semple
# Duplicate person: Robert_Tyler_(Confederate_Register_of_the_Treasury)
# Duplicate person: David_Gardiner_Tyler
# Duplicate person: John_Alexander_Tyler
# Duplicate person: Lyon_Gardiner_Tyler
# Duplicate person: Eliza_Monroe_Hay
# Duplicate person: Maria_Hester_Monroe_Gouverneur
# Duplicate person: George_Washington_Adams
# Duplicate person: John_Adams_II
# Duplicate person: Charles_Francis_Adams_Sr.
# Duplicate person: John_Parke_Custis
# Duplicate person: Martha_%22Patsy%22_Parke_Custis
# Duplicate person: Lyncoya_Jackson
# Duplicate person: Abigail_Adams_Smith
# Duplicate person: John_Quincy_Adams
# Duplicate person: Charles_Adams_(1770%E2%80%931800)
# Duplicate person: Thomas_Boylston_Adams_(1772%E2%80%931832)
# Duplicate person: Millard_Powers_Fillmore
# Duplicate person: Mary_Abigail_Fillmore
# Duplicate person: Martha_Jefferson_Randolph
# Duplicate person: Mary_Jefferson_Eppes
# Duplicate person: Sally_Hemings
# Duplicate person: Madison_Hemings
# Duplicate person: Eston_Hemings
# Duplicate person: Webb_C._Hayes
# Duplicate person: Rutherford_P._Hayes
# Duplicate person: Russell_Benjamin_Harrison
# Duplicate person: Mary_Harrison_McKee
# Duplicate person: Elizabeth_Harrison_Walker
# Duplicate person: Ruth_Cleveland
# Duplicate person: Esther_Cleveland
# Duplicate person: Richard_F._Cleveland
# Duplicate person: Harry_Augustus_Garfield
# Duplicate person: James_Rudolph_Garfield
# Duplicate person: Abram_Garfield
# Duplicate person: Chester_Alan_Arthur_II
# Duplicate person: Robert_A._Taft
# Duplicate person: Helen_Taft_Manning
# Duplicate person: Charles_Phelps_Taft_II
# Duplicate person: Elizabeth_Ann_Blaesing
# Duplicate person: Nan_Britton
# Duplicate person: John_Coolidge
# Duplicate person: Herbert_Hoover_Jr.
# Duplicate person: Allan_Hoover
# Duplicate person: Franklin_D._Roosevelt_Jr.
# Duplicate person: Anna_Roosevelt_Halsted
# Duplicate person: Elliott_Roosevelt_(general)
# Duplicate person: James_Roosevelt
# Duplicate person: John_Aspinwall_Roosevelt
# Duplicate person: Caroline_Kennedy
# Duplicate person: John_F._Kennedy_Jr.
# Duplicate person: Patrick_Bouvier_Kennedy
# Duplicate person: John_Eisenhower
# Duplicate person: Margaret_Truman
# Duplicate person: Michael_Gerald_Ford
# Duplicate person: John_Gardner_Ford
# Duplicate person: Steven_Ford
# Duplicate person: Susan_Ford
# Duplicate person: Tricia_Nixon_Cox
# Duplicate person: Julie_Nixon_Eisenhower
# Duplicate person: George_W._Bush
# Duplicate person: Pauline_Robinson_Bush
# Duplicate person: Jeb_Bush
# Duplicate person: Neil_Bush
# Duplicate person: Marvin_Bush
# Duplicate person: Dorothy_Bush_Koch
# Duplicate person: Maureen_Reagan
# Duplicate person: Michael_Reagan
# Duplicate person: Patti_Davis
# Duplicate person: Ron_Reagan
# Duplicate person: Jack_Carter_(politician)
# Duplicate person: Amy_Carter
# Duplicate person: Lynda_Bird_Johnson_Robb
# Duplicate person: Luci_Baines_Johnson
# Duplicate person: Barbara_Bush_(born_1981)
# Duplicate person: Jenna_Bush_Hager
# Duplicate person: Beau_Biden
# Duplicate person: Hunter_Biden
# Duplicate person: Naomi_Biden
# Duplicate person: Ashley_Biden
# Duplicate person: Ella_Emhoff
# Duplicate person: Maria_Vorontsova
# Duplicate person: Katerina_Tikhonova
# Duplicate person: Xi_Mingze
# Duplicate person: Victoria_Riskin
# Duplicate person: Tazewell_Tyler
# Duplicate person: John_Payne_Todd
# Duplicate person: Sarah_Knox_Taylor
# Duplicate person: Mary_Elizabeth_Bliss
# Duplicate person: Richard_Taylor_(Confederate_general)
# Duplicate person: Robert_Todd_Lincoln
# Duplicate person: Edward_Baker_Lincoln
# Duplicate person: William_Wallace_Lincoln
# Duplicate person: Tad_Lincoln
# Duplicate person: Frederick_Dent_Grant
# Duplicate person: Ulysses_S._Grant_Jr.
# Duplicate person: Nellie_Grant
# Duplicate person: Jesse_Root_Grant_(politician)
# Duplicate person: Martha_Johnson_Patterson
# Duplicate person: Marshall_Eugene_DeWolfe
# Duplicate person: Lynda_Johnson
# Duplicate person: Luci_Johnson
# Duplicate person: Alice_Roosevelt_Longworth
# Duplicate person: Theodore_Roosevelt_Jr.
# Duplicate person: Kermit_Roosevelt
# Duplicate person: Ethel_Roosevelt_Derby
# Duplicate person: Archibald_Roosevelt
# Duplicate person: Quentin_Roosevelt
# Duplicate person: Franklin_Delano_Roosevelt_Jr.
# Duplicate person: Margaret_Woodrow_Wilson
# Duplicate person: Jessie_Woodrow_Wilson_Sayre
# Duplicate person: Eleanor_Wilson_McAdoo
# Duplicate person: Donald_Trump_Jr.
# Duplicate person: Ivanka_Trump
# Duplicate person: Eric_Trump
# Duplicate person: Tiffany_Trump
# Duplicate person: Dan_Quayle
# Duplicate person: Malia_Obama
# Duplicate person: Sasha_Obama
# Duplicate person: Family_of_Donald_Trump#Barron_Trump
# Duplicate person: Justin_Trudeau
# Duplicate person: Alexandre_Trudeau
# Duplicate person: Michel_Trudeau
# Duplicate person: Qi_Qiaoqiao
# Duplicate person: Xi_Jinping
# Duplicate person: Xi_Yuanping
# Duplicate person: Bill_Clinton
# Duplicate person: Roger_Clinton_Jr.
# Duplicate person: Hillary_Clinton
# Duplicate person: Hugh_Edwin_Rodham
# Duplicate person: Tony_Rodham
# Duplicate person: Hugh_Rodham_(born_1950)
# Duplicate person: Kamala_Harris
# Duplicate person: Maya_Harris
# Duplicate person: Neil_Gorsuch
# Duplicate person: F._R._Scott
# Duplicate person: John_Marshall_Harlan_II
# Duplicate person: Bob_Hawke
# Duplicate person: David_Boren
# Duplicate person: Ian_Wilson_(politician)
# Duplicate person: Kim_Beazley
# Duplicate person: William_A._Fletcher
# Duplicate person: Susan_Rice
# Duplicate person: Malcolm_Turnbull
# Duplicate person: Pete_Buttigieg
# Duplicate person: Tomasz_Malinowski
# Duplicate person: Ches_Crosbie
# Duplicate person: Ronan_Farrow
# Duplicate person: Moses_Farrow
# Duplicate person: Soon-Yi_Previn
# Duplicate person: James_Madison
# Duplicate person: William_Madison
# Duplicate person: Dylan_Farrow
# Duplicate person: John_Adams
# Duplicate person: Elihu_Adams
# Duplicate person: Zachary_Taylor
# Duplicate person: Joseph_Pannell_Taylor
# Duplicate person: Benjamin_Harrison_VI
# Duplicate person: William_Henry_Harrison
# Duplicate person: John_Tyler
# Duplicate person: Martin_Van_Buren
# Duplicate person: Millard_Fillmore
# Duplicate person: Benjamin_Kendrick_Pierce
# Duplicate person: Franklin_Pierce
# Duplicate person: Warren_G._Harding
# Duplicate person: William_McKinley
# Duplicate person: Bamie_Roosevelt
# Duplicate person: Theodore_Roosevelt
# Duplicate person: Elliott_Bulloch_Roosevelt
# Duplicate person: Corinne_Roosevelt_Robinson
# Duplicate person: Elliott_Roosevelt_(socialite)
# Duplicate person: Lyndon_B._Johnson
# Duplicate person: Sam_Houston_Johnson
# Duplicate person: Charles_Phelps_Taft
# Duplicate person: William_Howard_Taft
# Duplicate person: Henry_Waters_Taft
# Duplicate person: Horace_Dutton_Taft
# Duplicate person: Calvin_Coolidge
# Duplicate person: James_Roosevelt_Roosevelt
# Duplicate person: Franklin_D._Roosevelt
# Duplicate person: Harry_S_Truman
# Duplicate person: Richard_Nixon
# Duplicate person: Francis_Donald_Nixon
# Duplicate person: Arthur_Nixon
# Duplicate person: Edward_Nixon
# Duplicate person: Arthur_Burdg_Nixon
# Duplicate person: Edward_Calvert_Nixon
# Duplicate person: Gerald_Ford
# Duplicate person: Neil_Reagan
# Duplicate person: Ronald_Reagan
# Duplicate person: Jimmy_Carter
# Duplicate person: Gloria_Carter_Spann
# Duplicate person: Ruth_Carter_Stapleton
# Duplicate person: Billy_Carter
# Duplicate person: Thomas_Gardner_Ford
# Duplicate person: Malik_Obama
# Duplicate person: Auma_Obama
# Duplicate person: Barack_Obama
# Duplicate person: Maryanne_Trump_Barry
# Duplicate person: Fred_Trump_Jr.
# Duplicate person: Elizabeth_Trump_Grau
# Duplicate person: Donald_Trump
# Duplicate person: Robert_Trump
# Duplicate person: Maya_Soetoro-Ng
# Duplicate person: Family_of_Donald_Trump#Elizabeth_Trump_Grau
# Duplicate person: Rachel_Manley
# Duplicate person: Thomas_Jefferson_Randolph
# Duplicate person: Ellen_Wayles_Randolph
# Duplicate person: Cornelia_Jefferson_Randolph
# Duplicate person: George_W._Randolph
# Duplicate person: Harrison_Ruffin_Tyler
# Duplicate person: Mamie_Lincoln_Isham
# Duplicate person: Jessie_Harlan_Lincoln
# Duplicate person: John_Quincy_Adams_II
# Duplicate person: Charles_Francis_Adams_Jr.
# Duplicate person: Henry_Adams
# Duplicate person: Brooks_Adams
# Duplicate person: Algernon_Edward_Sartoris
# Duplicate person: Julia_Dent_Cantacuz%C3%A8ne_Spiransky-Grant
# Duplicate person: Ulysses_S._Grant_III
# Duplicate person: Chapman_Grant
# Duplicate person: Philippa_Foot
# Duplicate person: William_Henry_Harrison_III
# Duplicate person: Gavin_Arthur
# Duplicate person: Seth_Taft
# Duplicate person: Grace_Roosevelt_McMillan
# Duplicate person: Theodore_Roosevelt_III
# Duplicate person: Cornelius_V.S._Roosevelt
# Duplicate person: Quentin_Roosevelt_II
# Duplicate person: William_Howard_Taft_III
# Duplicate person: Robert_Taft_Jr.
# Duplicate person: Edith_Derby_Williams
# Duplicate person: Kermit_Roosevelt_Jr.
# Duplicate person: Joseph_Willard_Roosevelt
# Duplicate person: Eleanor_Roosevelt_Seagraves
# Duplicate person: Curtis_Roosevelt
# Duplicate person: John_Roosevelt_Boettiger
# Duplicate person: Franklin_D._Roosevelt_III
# Duplicate person: Archibald_Bulloch_Roosevelt_Jr.
# Duplicate person: Theodora_Keogh
# Duplicate person: Francis_Bowes_Sayre_Jr.
# Duplicate person: Eleanor_Sayre
# Duplicate person: Sara_Wilford
# Duplicate person: James_Roosevelt_(lawyer)
# Duplicate person: Christopher_Nixon_Cox
# Duplicate person: David_Eisenhower
# Duplicate person: Anne_Eisenhower
# Duplicate person: Susan_Eisenhower
# Duplicate person: Mary_Jean_Eisenhower
# Duplicate person: Rose_Schlossberg
# Duplicate person: Tatiana_Schlossberg
# Duplicate person: Jack_Schlossberg
# Duplicate person: Clifton_Truman_Daniel
# Duplicate person: mw-data:TemplateStyles:r1066479718
# Duplicate person: Jennie_Eisenhower
# Duplicate person: Lauren_Bush
# Duplicate person: Jason_Carter_(politician)
# Duplicate person: George_P._Bush
# Duplicate person: Lucy_Turnbull
# Duplicate person: Mary_Todd_Lincoln
# Duplicate person: Eleanor_Roosevelt
# Duplicate person: Jacqueline_Kennedy_Onassis
# Duplicate person: Nancy_Reagan
# Duplicate person: Barbara_Bush
# Duplicate person: Pierre_Trudeau
# Duplicate person: Michelle_Obama
# Duplicate person: John_Maynard_Harlan
# Duplicate person: Blair_Clark
# Duplicate person: Samuel_Ealy_Johnson_Jr.
# Duplicate person: James_Madison_Sr.
# Duplicate person: Leslie_Lynch_King_Sr.
# Duplicate person: Fred_Trump
# Duplicate person: Ann_Dunham

# %%
len(people_list)
# Out:
# 1804

# %%
csv_writer('wikicrawler/people.csv', people_list)

# %% [markdown]
# ## Data Cleaning

# %%
df = pd.read_csv('wikicrawler/people_data_temp.csv')
df
# Out:
#                                                 schools    degrees  \
# 0                            London School of Economics    MSc,BSc
# 1     Yale University,University of Wyoming,Universi...      MA,BA
# 2                                University of Fribourg        NaN
# 3     DePauw University,Indiana University, Indianap...      BA,JD
# 4     Dartmouth College,University College, Oxford,Y...   MA,BA,JD
# ...                                                 ...        ...
# 1310                          Harvard University,BA,MBA        NaN
# 1311                                 Harvard University     BA,LLB
# 1312                 Harvard University,Yale University      JD,AB
# 1313  Yale University,Princeton University,Universit...   MA,BA,JD
# 1314                                 Harvard University  PhD,JD,BA
#
#                            name                 full_name  \
# 0                  George Soros           György Schwartz
# 1                   Dick Cheney      Richard Bruce Cheney
# 2                  Klaus Schwab                       NaN
# 3                    Dan Quayle     James Danforth Quayle
# 4                  Robert Reich      Robert Bernard Reich
# ...                         ...                       ...
# 1310       Theodore Roosevelt V      Theodore Roosevelt V
# 1311  Charles Francis Adams III                       NaN
# 1312       Kermit Roosevelt III                       NaN
# 1313                   Bob Taft  Robert Alphonso Taft III
# 1314       Susan Roosevelt Weld           Susan Roosevelt
#
#                       DOB                                         occupation  \
# 0     1930-08-12 00:00:00  Investor, hedge fund manager, author, philanth...
# 1     1941-01-30 00:00:00                                                NaN
# 2     1938-03-30 00:00:00                               World Economic Forum
# 3     1947-02-04 00:00:00                                                NaN
# 4     1946-06-24 00:00:00                                                NaN
# ...                   ...                                                ...
# 1310  1942-11-27 00:00:00                                                NaN
# 1311  1866-08-02 00:00:00                                                NaN
# 1312  1971-07-14 00:00:00                                                NaN
# 1313  1942-01-08 00:00:00                                                NaN
# 1314                  NaN                       Lawyer, academic, politician
#
#                                                 spouses  \
# 0                               Susan Weber (historian)
# 1                                          Lynne Cheney
# 2                                          Hilde Schwab
# 3                                        Marilyn Quayle
# 4                                          Clare Dalton
# ...                                                 ...
# 1310                              Constance Lane Rogers
# 1311  index.php?title=Frances Adams&action=edit&redl...
# 1312                                                NaN
# 1313                                                NaN
# 1314                                          Bill Weld
#
#                            offspring
# 0     Jonathan Soros,Alexander Soros
# 1             Liz Cheney,Mary Cheney
# 2                                  2
# 3                         Ben Quayle
# 4                          Sam Reich
# ...                              ...
# 1310           Theodore Roosevelt VI
# 1311        Charles Francis Adams IV
# 1312                             NaN
# 1313                       Anna Taft
# 1314                               5
#
# [1315 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1315 entries, 0 to 1314
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   schools     842 non-null    object
#  1   degrees     320 non-null    object
#  2   name        1233 non-null   object
#  3   full_name   581 non-null    object
#  4   DOB         1225 non-null   object
#  5   occupation  405 non-null    object
#  6   spouses     698 non-null    object
#  7   offspring   574 non-null    object
# dtypes: object(8)
# memory usage: 82.3+ KB

# %%
df_full = df.dropna(how='all')
df_full
# Out:
#                                                 schools    degrees  \
# 0                            London School of Economics    MSc,BSc
# 1     Yale University,University of Wyoming,Universi...      MA,BA
# 2                                University of Fribourg        NaN
# 3     DePauw University,Indiana University, Indianap...      BA,JD
# 4     Dartmouth College,University College, Oxford,Y...   MA,BA,JD
# ...                                                 ...        ...
# 1310                          Harvard University,BA,MBA        NaN
# 1311                                 Harvard University     BA,LLB
# 1312                 Harvard University,Yale University      JD,AB
# 1313  Yale University,Princeton University,Universit...   MA,BA,JD
# 1314                                 Harvard University  PhD,JD,BA
#
#                            name                 full_name  \
# 0                  George Soros           György Schwartz
# 1                   Dick Cheney      Richard Bruce Cheney
# 2                  Klaus Schwab                       NaN
# 3                    Dan Quayle     James Danforth Quayle
# 4                  Robert Reich      Robert Bernard Reich
# ...                         ...                       ...
# 1310       Theodore Roosevelt V      Theodore Roosevelt V
# 1311  Charles Francis Adams III                       NaN
# 1312       Kermit Roosevelt III                       NaN
# 1313                   Bob Taft  Robert Alphonso Taft III
# 1314       Susan Roosevelt Weld           Susan Roosevelt
#
#                       DOB                                         occupation  \
# 0     1930-08-12 00:00:00  Investor, hedge fund manager, author, philanth...
# 1     1941-01-30 00:00:00                                                NaN
# 2     1938-03-30 00:00:00                               World Economic Forum
# 3     1947-02-04 00:00:00                                                NaN
# 4     1946-06-24 00:00:00                                                NaN
# ...                   ...                                                ...
# 1310  1942-11-27 00:00:00                                                NaN
# 1311  1866-08-02 00:00:00                                                NaN
# 1312  1971-07-14 00:00:00                                                NaN
# 1313  1942-01-08 00:00:00                                                NaN
# 1314                  NaN                       Lawyer, academic, politician
#
#                                                 spouses  \
# 0                               Susan Weber (historian)
# 1                                          Lynne Cheney
# 2                                          Hilde Schwab
# 3                                        Marilyn Quayle
# 4                                          Clare Dalton
# ...                                                 ...
# 1310                              Constance Lane Rogers
# 1311  index.php?title=Frances Adams&action=edit&redl...
# 1312                                                NaN
# 1313                                                NaN
# 1314                                          Bill Weld
#
#                            offspring
# 0     Jonathan Soros,Alexander Soros
# 1             Liz Cheney,Mary Cheney
# 2                                  2
# 3                         Ben Quayle
# 4                          Sam Reich
# ...                              ...
# 1310           Theodore Roosevelt VI
# 1311        Charles Francis Adams IV
# 1312                             NaN
# 1313                       Anna Taft
# 1314                               5
#
# [1297 rows x 8 columns]

# %%
# Drop all rows without a name
df_all_names = df_full.dropna(subset=['name'])
df_all_names
# Out:
#                                                 schools    degrees  \
# 0                            London School of Economics    MSc,BSc
# 1     Yale University,University of Wyoming,Universi...      MA,BA
# 2                                University of Fribourg        NaN
# 3     DePauw University,Indiana University, Indianap...      BA,JD
# 4     Dartmouth College,University College, Oxford,Y...   MA,BA,JD
# ...                                                 ...        ...
# 1310                          Harvard University,BA,MBA        NaN
# 1311                                 Harvard University     BA,LLB
# 1312                 Harvard University,Yale University      JD,AB
# 1313  Yale University,Princeton University,Universit...   MA,BA,JD
# 1314                                 Harvard University  PhD,JD,BA
#
#                            name                 full_name  \
# 0                  George Soros           György Schwartz
# 1                   Dick Cheney      Richard Bruce Cheney
# 2                  Klaus Schwab                       NaN
# 3                    Dan Quayle     James Danforth Quayle
# 4                  Robert Reich      Robert Bernard Reich
# ...                         ...                       ...
# 1310       Theodore Roosevelt V      Theodore Roosevelt V
# 1311  Charles Francis Adams III                       NaN
# 1312       Kermit Roosevelt III                       NaN
# 1313                   Bob Taft  Robert Alphonso Taft III
# 1314       Susan Roosevelt Weld           Susan Roosevelt
#
#                       DOB                                         occupation  \
# 0     1930-08-12 00:00:00  Investor, hedge fund manager, author, philanth...
# 1     1941-01-30 00:00:00                                                NaN
# 2     1938-03-30 00:00:00                               World Economic Forum
# 3     1947-02-04 00:00:00                                                NaN
# 4     1946-06-24 00:00:00                                                NaN
# ...                   ...                                                ...
# 1310  1942-11-27 00:00:00                                                NaN
# 1311  1866-08-02 00:00:00                                                NaN
# 1312  1971-07-14 00:00:00                                                NaN
# 1313  1942-01-08 00:00:00                                                NaN
# 1314                  NaN                       Lawyer, academic, politician
#
#                                                 spouses  \
# 0                               Susan Weber (historian)
# 1                                          Lynne Cheney
# 2                                          Hilde Schwab
# 3                                        Marilyn Quayle
# 4                                          Clare Dalton
# ...                                                 ...
# 1310                              Constance Lane Rogers
# 1311  index.php?title=Frances Adams&action=edit&redl...
# 1312                                                NaN
# 1313                                                NaN
# 1314                                          Bill Weld
#
#                            offspring
# 0     Jonathan Soros,Alexander Soros
# 1             Liz Cheney,Mary Cheney
# 2                                  2
# 3                         Ben Quayle
# 4                          Sam Reich
# ...                              ...
# 1310           Theodore Roosevelt VI
# 1311        Charles Francis Adams IV
# 1312                             NaN
# 1313                       Anna Taft
# 1314                               5
#
# [1233 rows x 8 columns]

# %%
df_all_names.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1233 entries, 0 to 1314
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   schools     835 non-null    object
#  1   degrees     320 non-null    object
#  2   name        1233 non-null   object
#  3   full_name   581 non-null    object
#  4   DOB         1163 non-null   object
#  5   occupation  405 non-null    object
#  6   spouses     697 non-null    object
#  7   offspring   573 non-null    object
# dtypes: object(8)
# memory usage: 86.7+ KB

# %%
df_no_gaps = df_all_names.drop_duplicates()
df_no_gaps
# Out:
#                                                 schools    degrees  \
# 0                            London School of Economics    MSc,BSc
# 1     Yale University,University of Wyoming,Universi...      MA,BA
# 2                                University of Fribourg        NaN
# 3     DePauw University,Indiana University, Indianap...      BA,JD
# 4     Dartmouth College,University College, Oxford,Y...   MA,BA,JD
# ...                                                 ...        ...
# 1310                          Harvard University,BA,MBA        NaN
# 1311                                 Harvard University     BA,LLB
# 1312                 Harvard University,Yale University      JD,AB
# 1313  Yale University,Princeton University,Universit...   MA,BA,JD
# 1314                                 Harvard University  PhD,JD,BA
#
#                            name                 full_name  \
# 0                  George Soros           György Schwartz
# 1                   Dick Cheney      Richard Bruce Cheney
# 2                  Klaus Schwab                       NaN
# 3                    Dan Quayle     James Danforth Quayle
# 4                  Robert Reich      Robert Bernard Reich
# ...                         ...                       ...
# 1310       Theodore Roosevelt V      Theodore Roosevelt V
# 1311  Charles Francis Adams III                       NaN
# 1312       Kermit Roosevelt III                       NaN
# 1313                   Bob Taft  Robert Alphonso Taft III
# 1314       Susan Roosevelt Weld           Susan Roosevelt
#
#                       DOB                                         occupation  \
# 0     1930-08-12 00:00:00  Investor, hedge fund manager, author, philanth...
# 1     1941-01-30 00:00:00                                                NaN
# 2     1938-03-30 00:00:00                               World Economic Forum
# 3     1947-02-04 00:00:00                                                NaN
# 4     1946-06-24 00:00:00                                                NaN
# ...                   ...                                                ...
# 1310  1942-11-27 00:00:00                                                NaN
# 1311  1866-08-02 00:00:00                                                NaN
# 1312  1971-07-14 00:00:00                                                NaN
# 1313  1942-01-08 00:00:00                                                NaN
# 1314                  NaN                       Lawyer, academic, politician
#
#                                                 spouses  \
# 0                               Susan Weber (historian)
# 1                                          Lynne Cheney
# 2                                          Hilde Schwab
# 3                                        Marilyn Quayle
# 4                                          Clare Dalton
# ...                                                 ...
# 1310                              Constance Lane Rogers
# 1311  index.php?title=Frances Adams&action=edit&redl...
# 1312                                                NaN
# 1313                                                NaN
# 1314                                          Bill Weld
#
#                            offspring
# 0     Jonathan Soros,Alexander Soros
# 1             Liz Cheney,Mary Cheney
# 2                                  2
# 3                         Ben Quayle
# 4                          Sam Reich
# ...                              ...
# 1310           Theodore Roosevelt VI
# 1311        Charles Francis Adams IV
# 1312                             NaN
# 1313                       Anna Taft
# 1314                               5
#
# [1202 rows x 8 columns]

# %%
df_no_gaps.to_csv('wikicrawler/people_data.csv')

# %%
df_degrees = df_no_gaps.dropna(subset=['schools', 'degrees'])

# %%
# Rearrange columns and sort on name
df_degrees = df_degrees[['name', 'full_name', 'DOB', 'occupation', 'schools', 'degrees', 'spouses', 'offspring']]
df_degrees.sort_values(by='name', ignore_index=True, inplace=True)
df_degrees
# Out:
#                        name                     full_name  \
# 0        A. Clayton Spencer           Ava Clayton Spencer
# 1            Abdul El-Sayed  Abdulrahman Mohamed El-Sayed
# 2               Alan Bersin                           NaN
# 3    Alan Chester Valentine                           NaN
# 4            Alan Greenspan                           NaN
# ..                      ...                           ...
# 308          William McAdoo      William Gibbs McAdoo Jr.
# 309           William McRae       William Allan McRae Jr.
# 310            William Taft                           NaN
# 311           Wilson Elkins           Wilson Homer Elkins
# 312               Xi Mingze                           习明泽
#
#                      DOB occupation  \
# 0    1954-12-15 00:00:00        NaN
# 1    1984-10-31 00:00:00        NaN
# 2    1946-10-15 00:00:00        NaN
# 3    1901-02-23 00:00:00        NaN
# 4    1926-03-06 00:00:00        NaN
# ..                   ...        ...
# 308  1863-10-31 00:00:00        NaN
# 309  1909-09-25 00:00:00        NaN
# 310  1945-09-13 00:00:00        NaN
# 311  1908-07-09 00:00:00        NaN
# 312  1992-06-25 00:00:00        NaN
#
#                                                schools  \
# 0    Williams College,University of Oxford,Harvard ...
# 1    University of Michigan,Oriel College, Oxford,C...
# 2                   Harvard University,Yale University
# 3    Swarthmore College,University of Pennsylvania,...
# 4                                  New York University
# ..                                                 ...
# 308                 University of Tennessee, Knoxville
# 309  University of Florida,University of Oxford,Fre...
# 310                 Yale University,Harvard University
# 311                        University of Texas, Austin
# 312                                 Harvard University
#
#                                                degrees                spouses  \
# 0                                             MA,BA,JD             Ash Carter
# 1                                         MA,PhD,MD,BS           Sarah Jukaku
# 2                                                BA,JD            Lisa Foster
# 3    University of Pennsylvania,Balliol College, Ox...  Lucia Garrison Norton
# 4                                            PhD,MA,BA        Andrea Mitchell
# ..                                                 ...                    ...
# 308                                                 BA  Eleanor Wilson McAdoo
# 309      B.A.,J.D.,B.Litt.,A.B.,B.A.,J.D.,B.Litt.,A.B.                    NaN
# 310                                              BA,JD          Julia V. Taft
# 311                                              MA,BA     Dorothy Blackburn
# 312                                                 BA                    NaN
#
#                   offspring
# 0                         2
# 1                       NaN
# 2                       NaN
# 3    Annie Laurie Buffinton
# 4                       NaN
# ..                      ...
# 308                       9
# 309                     NaN
# 310                       3
# 311                       2
# 312                     NaN
#
# [313 rows x 8 columns]

# %%
df_degrees.set_index('name', drop=True, inplace=True)
df_degrees
# Out:
#                                            full_name                  DOB  \
# name
# A. Clayton Spencer               Ava Clayton Spencer  1954-12-15 00:00:00
# Abdul El-Sayed          Abdulrahman Mohamed El-Sayed  1984-10-31 00:00:00
# Alan Bersin                                      NaN  1946-10-15 00:00:00
# Alan Chester Valentine                           NaN  1901-02-23 00:00:00
# Alan Greenspan                                   NaN  1926-03-06 00:00:00
# ...                                              ...                  ...
# William McAdoo              William Gibbs McAdoo Jr.  1863-10-31 00:00:00
# William McRae                William Allan McRae Jr.  1909-09-25 00:00:00
# William Taft                                     NaN  1945-09-13 00:00:00
# Wilson Elkins                    Wilson Homer Elkins  1908-07-09 00:00:00
# Xi Mingze                                        习明泽  1992-06-25 00:00:00
#
#                        occupation  \
# name
# A. Clayton Spencer            NaN
# Abdul El-Sayed                NaN
# Alan Bersin                   NaN
# Alan Chester Valentine        NaN
# Alan Greenspan                NaN
# ...                           ...
# William McAdoo                NaN
# William McRae                 NaN
# William Taft                  NaN
# Wilson Elkins                 NaN
# Xi Mingze                     NaN
#
#                                                                   schools  \
# name
# A. Clayton Spencer      Williams College,University of Oxford,Harvard ...
# Abdul El-Sayed          University of Michigan,Oriel College, Oxford,C...
# Alan Bersin                            Harvard University,Yale University
# Alan Chester Valentine  Swarthmore College,University of Pennsylvania,...
# Alan Greenspan                                        New York University
# ...                                                                   ...
# William McAdoo                         University of Tennessee, Knoxville
# William McRae           University of Florida,University of Oxford,Fre...
# William Taft                           Yale University,Harvard University
# Wilson Elkins                                 University of Texas, Austin
# Xi Mingze                                              Harvard University
#
#                                                                   degrees  \
# name
# A. Clayton Spencer                                               MA,BA,JD
# Abdul El-Sayed                                               MA,PhD,MD,BS
# Alan Bersin                                                         BA,JD
# Alan Chester Valentine  University of Pennsylvania,Balliol College, Ox...
# Alan Greenspan                                                  PhD,MA,BA
# ...                                                                   ...
# William McAdoo                                                         BA
# William McRae               B.A.,J.D.,B.Litt.,A.B.,B.A.,J.D.,B.Litt.,A.B.
# William Taft                                                        BA,JD
# Wilson Elkins                                                       MA,BA
# Xi Mingze                                                              BA
#
#                                       spouses               offspring
# name
# A. Clayton Spencer                 Ash Carter                       2
# Abdul El-Sayed                   Sarah Jukaku                     NaN
# Alan Bersin                       Lisa Foster                     NaN
# Alan Chester Valentine  Lucia Garrison Norton  Annie Laurie Buffinton
# Alan Greenspan                Andrea Mitchell                     NaN
# ...                                       ...                     ...
# William McAdoo          Eleanor Wilson McAdoo                       9
# William McRae                             NaN                     NaN
# William Taft                    Julia V. Taft                       3
# Wilson Elkins              Dorothy Blackburn                        2
# Xi Mingze                                 NaN                     NaN
#
# [313 rows x 7 columns]

# %%
# df_degrees = df_degrees.replace({np.nan:None})

# %%
def date_converter(x):
    if x:
        if '-' in x:
            updated = dt.strptime(str(x), '%Y-%m-%d %H:%M:%S')
        elif '/' in x:
            updated = dt.strptime(str(x), '%m/%d/%Y %H:%M:%S')
        else:
            return None
        print(updated)
        return updated.strftme('%Y-%m-%d')        
    else:
        return None

# %%
# df_degrees['DOB'] = np.vectorize(date_converter)(df_degrees['DOB'])
df_degrees['DOB'] = pd.to_datetime(df_degrees.DOB)
df_degrees['DOB'] = df_degrees['DOB'].dt.strftime('%Y-%m-%d')
df_degrees
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\python37\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    2058         try:
# -> 2059             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    2060             # If tzaware, these values represent unix timestamps, so we
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-457-fcdd8fd3b472> in <module>
#       1 # df_degrees['DOB'] = np.vectorize(date_converter)(df_degrees['DOB'])
# ----> 2 df_degrees['DOB'] = pd.to_datetime(df_degrees.DOB)
#       3 df_degrees['DOB'] = df_degrees['DOB'].dt.strftime('%Y-%m-%d')
#       4 df_degrees
#
# c:\python37\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     801             result = arg.map(cache_array)
#     802         else:
# --> 803             values = convert_listlike(arg._values, format)
#     804             result = arg._constructor(values, index=arg.index, name=arg.name)
#     805     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# c:\python37\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     464             errors=errors,
#     465             require_iso8601=require_iso8601,
# --> 466             allow_object=True,
#     467         )
#     468
#
# c:\python37\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    2062             return values.view("i8"), tz_parsed
#    2063         except (ValueError, TypeError):
# -> 2064             raise e
#    2065
#    2066     if tz_parsed is not None:
#
# c:\python37\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    2053             dayfirst=dayfirst,
#    2054             yearfirst=yearfirst,
# -> 2055             require_iso8601=require_iso8601,
#    2056         )
#    2057     except ValueError as e:
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime_object()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime_object()
#
# pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# c:\python37\lib\site-packages\dateutil\parser\_parser.py in parse(timestr, parserinfo, **kwargs)
#    1354         return parser(parserinfo).parse(timestr, **kwargs)
#    1355     else:
# -> 1356         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1357
#    1358
#
# c:\python37\lib\site-packages\dateutil\parser\_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     646
#     647         if res is None:
# --> 648             raise ValueError("Unknown string format:", timestr)
#     649
#     650         if len(res) == 0:
#
# ValueError: ('Unknown string format:', '1989 or 1990 (age\xa031–32)')

# %%
df_degrees.to_csv('wikicrawler/people_data_full.csv')

# %% [markdown]
# ## Rhodes Scholars

# %%
rhodes_df = pd.read_csv('rhodescholars/rhodes_data.csv')
rhodes_df

# %%
df_occupations = rhodes_df.merge(df_no_gaps, on='name', how='outer')
df_occupations

# %%
df_occupations.to_csv('wikicrawler/merged_occupations.csv')
